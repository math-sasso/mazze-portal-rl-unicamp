# %% [markdown]
# # $$ Q - Learning $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os

from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler
import sklearn.pipeline
import sklearn.preprocessing

# imports from project
#from utils.plotting import plot_line_graphs_overlayed
#from utils.file_management import create_folder_structure
#from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","Q_LEANING")
SAVING_RESULTS_FODLER
# Out:
# 'C:\\Users\\lucas\\OneDrive\\Documentos\\UNESP\\UNICAMP\\RL\\projeto 1\\mazze-portal-rl-unicamp\\results\\Q_LEANING'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-random-10x10-plus-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
MIN_LEARNING_RATE = 0.2
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 1000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99

'''
CREATING RESULTS SAVING FOLDERS
'''

SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
#create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
#create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
#create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)

# %%
# Feature Preprocessing: Normalize to zero mean and unit variance
# We use a few samples from the observation space to do this
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(observation_examples)

# Used to converte a state to a featurizes represenation.
# We use RBF kernels with different variances to cover different parts of the space
featurizer = sklearn.pipeline.FeatureUnion([
        ("rbf1", RBFSampler(gamma=5.0, n_components=100)),
        ("rbf2", RBFSampler(gamma=2.0, n_components=100)),
        ("rbf3", RBFSampler(gamma=1.0, n_components=100)),
        ("rbf4", RBFSampler(gamma=0.5, n_components=100))
        ])
featurizer.fit(scaler.transform(observation_examples))
# Out:
# FeatureUnion(n_jobs=None,
#              transformer_list=[('rbf1',
#                                 RBFSampler(gamma=5.0, n_components=100,
#                                            random_state=None)),
#                                ('rbf2',
#                                 RBFSampler(gamma=2.0, n_components=100,
#                                            random_state=None)),
#                                ('rbf3',
#                                 RBFSampler(gamma=1.0, n_components=100,
#                                            random_state=None)),
#                                ('rbf4',
#                                 RBFSampler(gamma=0.5, n_components=100,
#                                            random_state=None))],
#              transformer_weights=None, verbose=False)

# %%
class Estimator():
    """
    Value Function approximator.
    """

    def __init__(self):
        # We create a separate model for each action in the environment's
        # action space. Alternatively we could somehow encode the action
        # into the features, but this way it's easier to code up.
        self.models = []
        for _ in range(env.action_space.n):
            model = SGDRegressor(learning_rate="constant")
            # We need to call partial_fit once to initialize the model
            # or we get a NotFittedError when trying to make a prediction
            # This is quite hacky.
            model.partial_fit([self.featurize_state(env.reset())], [0])
            self.models.append(model)

        pdb.set_trace()
    def featurize_state(self, state):
        """
        Returns the featurized representation for a state.
        """
        scaled = scaler.transform([state])
        featurized = featurizer.transform(scaled)

        #print('state',state)
        #print('feature', np.shape(featurized[0]))

        return featurized[0]

    def predict(self, s, a=None):
        """
        Makes value function predictions.

        Args:
            s: state to make a prediction for
            a: (Optional) action to make a prediction for

        Returns
            If an action a is given this returns a single number as the prediction.
            If no action is given this returns a vector or predictions for all actions
            in the environment where pred[i] is the prediction for action i.

        """
        features = self.featurize_state(s)
        if not a:
            return np.array([m.predict([features])[0] for m in self.models])
        else:
            return self.models[a].predict([features])[0]

    def update(self, s, a, y):
        """
        Updates the estimator parameters for a given state and action towards
        the target y.
        """
        features = self.featurize_state(s)
        self.models[a].partial_fit([features], [y])

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(learning_rate_episode_list): Numpy array with the episodes learning rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    learning_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    # Initialize weigths
    w = np.zeros(NUM_BUCKETS[0]*NUM_BUCKETS[1] * NUM_ACTIONS)
    
    #q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)

    #Initializain num streaks
    num_streaks= 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)
        total_reward = 0


        for t in range(MAX_T):

            # Select an action
            action = epsilon_greedy_police(state_0, explore_rate,q_table)

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)
            total_reward += reward

            # Update the Q based on the result
            best_q = np.amax(q_table[state])
            # q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * (best_q) - q_table[state_0 + (action,)])
            
            w += learning_rate * (reward + discount_factor * (best_q) - w*X)

            
            # Setting up for the next iteration
            state_0 = state


            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print(f"Episode {episode} finished after {t} time steps with total reward = {total_reward} (streak {num_streaks}).")

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print(f"Episode {episode} timed out at {t} with total reward = {total_reward}.")

        # Appending Episode values to the list
        reward_episode_list.append(total_reward)
        explore_rate_episode_list.append(explore_rate)
        learning_rate_episode_list.append(learning_rate)
        num_streaks_episode_list.append(num_streaks)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)


    print("FINAL ACTION TABLE \n")
    acts = ["N", "S", "E", "W"]
    for i in range(q_table.shape[2]):
        print(f"Action {acts[i]} table \n {q_table[:,:,i]}\n")

    return (np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(learning_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def epsilon_greedy_police(state, explore_rate,q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE and LEARNING_RATE

# %%
#GLIE
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %%
def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
reward_episode_array,explore_rate_episode_array,learning_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# Episode 0 finished after 1086 time steps with total reward = -0.0859999999999912 (streak 0).
# Episode 1 finished after 175 time steps with total reward = 0.8249999999999998 (streak 0).
# Episode 2 finished after 73 time steps with total reward = 0.9269999999999999 (streak 0).
# Episode 3 finished after 60 time steps with total reward = 0.94 (streak 1).
# Episode 4 finished after 369 time steps with total reward = 0.6309999999999998 (streak 2).
# Episode 5 finished after 38 time steps with total reward = 0.962 (streak 0).
# Episode 6 finished after 357 time steps with total reward = 0.6429999999999998 (streak 1).
# Episode 7 finished after 249 time steps with total reward = 0.7509999999999998 (streak 0).
# Episode 8 finished after 247 time steps with total reward = 0.7529999999999998 (streak 0).
# Episode 9 finished after 62 time steps with total reward = 0.938 (streak 0).
# Episode 10 finished after 86 time steps with total reward = 0.9139999999999999 (streak 1).
# Episode 11 finished after 380 time steps with total reward = 0.6199999999999997 (streak 2).
# Episode 12 finished after 95 time steps with total reward = 0.9049999999999999 (streak 0).
# Episode 13 finished after 212 time steps with total reward = 0.7879999999999998 (streak 1).
# Episode 14 finished after 130 time steps with total reward = 0.8699999999999999 (streak 0).
# Episode 15 finished after 107 time steps with total reward = 0.8929999999999999 (streak 0).
# Episode 16 finished after 146 time steps with total reward = 0.8539999999999999 (streak 0).
# Episode 17 finished after 57 time steps with total reward = 0.943 (streak 0).
# Episode 18 finished after 74 time steps with total reward = 0.9259999999999999 (streak 1).
# Episode 19 finished after 79 time steps with total reward = 0.9209999999999999 (streak 2).
# Episode 20 finished after 99 time steps with total reward = 0.9009999999999999 (streak 3).
# Episode 21 finished after 48 time steps with total reward = 0.952 (streak 4).
# Episode 22 finished after 72 time steps with total reward = 0.9279999999999999 (streak 5).
# Episode 23 finished after 53 time steps with total reward = 0.947 (streak 6).
# Episode 24 finished after 25 time steps with total reward = 0.975 (streak 7).
# Episode 25 finished after 48 time steps with total reward = 0.952 (streak 8).
# Episode 26 finished after 48 time steps with total reward = 0.952 (streak 9).
# Episode 27 finished after 25 time steps with total reward = 0.975 (streak 10).
# Episode 28 finished after 20 time steps with total reward = 0.98 (streak 11).
# Episode 29 finished after 50 time steps with total reward = 0.95 (streak 12).
# Episode 30 finished after 15 time steps with total reward = 0.985 (streak 13).
# Episode 31 finished after 18 time steps with total reward = 0.982 (streak 14).
# Episode 32 finished after 30 time steps with total reward = 0.97 (streak 15).
# Episode 33 finished after 48 time steps with total reward = 0.952 (streak 16).
# Episode 34 finished after 16 time steps with total reward = 0.984 (streak 17).
# Episode 35 finished after 17 time steps with total reward = 0.983 (streak 18).
# Episode 36 finished after 18 time steps with total reward = 0.982 (streak 19).
# Episode 37 finished after 13 time steps with total reward = 0.987 (streak 20).
# Episode 38 finished after 22 time steps with total reward = 0.978 (streak 21).
# Episode 39 finished after 21 time steps with total reward = 0.979 (streak 22).
# Episode 40 finished after 15 time steps with total reward = 0.985 (streak 23).
# Episode 41 finished after 34 time steps with total reward = 0.966 (streak 24).
# Episode 42 finished after 13 time steps with total reward = 0.987 (streak 25).
# Episode 43 finished after 12 time steps with total reward = 0.988 (streak 26).
# Episode 44 finished after 20 time steps with total reward = 0.98 (streak 27).
# Episode 45 finished after 20 time steps with total reward = 0.98 (streak 28).
# Episode 46 finished after 13 time steps with total reward = 0.987 (streak 29).
# Episode 47 finished after 16 time steps with total reward = 0.984 (streak 30).
# Episode 48 finished after 47 time steps with total reward = 0.953 (streak 31).
# Episode 49 finished after 18 time steps with total reward = 0.982 (streak 32).
# Episode 50 finished after 22 time steps with total reward = 0.978 (streak 33).
# Episode 51 finished after 16 time steps with total reward = 0.984 (streak 34).
# Episode 52 finished after 11 time steps with total reward = 0.989 (streak 35).
# Episode 53 finished after 12 time steps with total reward = 0.988 (streak 36).
# Episode 54 finished after 12 time steps with total reward = 0.988 (streak 37).
# Episode 55 finished after 18 time steps with total reward = 0.982 (streak 38).
# Episode 56 finished after 11 time steps with total reward = 0.989 (streak 39).
# Episode 57 finished after 25 time steps with total reward = 0.975 (streak 40).
# Episode 58 finished after 13 time steps with total reward = 0.987 (streak 41).
# Episode 59 finished after 27 time steps with total reward = 0.973 (streak 42).
# Episode 60 finished after 12 time steps with total reward = 0.988 (streak 43).
# Episode 61 finished after 12 time steps with total reward = 0.988 (streak 44).
# Episode 62 finished after 11 time steps with total reward = 0.989 (streak 45).
# Episode 63 finished after 13 time steps with total reward = 0.987 (streak 46).
# Episode 64 finished after 11 time steps with total reward = 0.989 (streak 47).
# Episode 65 finished after 11 time steps with total reward = 0.989 (streak 48).
# Episode 66 finished after 12 time steps with total reward = 0.988 (streak 49).
# Episode 67 finished after 23 time steps with total reward = 0.977 (streak 50).
# Episode 68 finished after 13 time steps with total reward = 0.987 (streak 51).
# Episode 69 finished after 16 time steps with total reward = 0.984 (streak 52).
# Episode 70 finished after 14 time steps with total reward = 0.986 (streak 53).
# Episode 71 finished after 14 time steps with total reward = 0.986 (streak 54).
# Episode 72 finished after 15 time steps with total reward = 0.985 (streak 55).
# Episode 73 finished after 14 time steps with total reward = 0.986 (streak 56).
# Episode 74 finished after 11 time steps with total reward = 0.989 (streak 57).
# Episode 75 finished after 14 time steps with total reward = 0.986 (streak 58).
# Episode 76 finished after 11 time steps with total reward = 0.989 (streak 59).
# Episode 77 finished after 13 time steps with total reward = 0.987 (streak 60).
# Episode 78 finished after 11 time steps with total reward = 0.989 (streak 61).
# Episode 79 finished after 11 time steps with total reward = 0.989 (streak 62).
# Episode 80 finished after 13 time steps with total reward = 0.987 (streak 63).
# Episode 81 finished after 11 time steps with total reward = 0.989 (streak 64).
# Episode 82 finished after 15 time steps with total reward = 0.985 (streak 65).
# Episode 83 finished after 17 time steps with total reward = 0.983 (streak 66).
# Episode 84 finished after 12 time steps with total reward = 0.988 (streak 67).
# Episode 85 finished after 11 time steps with total reward = 0.989 (streak 68).
# Episode 86 finished after 11 time steps with total reward = 0.989 (streak 69).
# Episode 87 finished after 11 time steps with total reward = 0.989 (streak 70).
# Episode 88 finished after 13 time steps with total reward = 0.987 (streak 71).
# Episode 89 finished after 12 time steps with total reward = 0.988 (streak 72).
# Episode 90 finished after 15 time steps with total reward = 0.985 (streak 73).
# Episode 91 finished after 11 time steps with total reward = 0.989 (streak 74).
# Episode 92 finished after 15 time steps with total reward = 0.985 (streak 75).
# Episode 93 finished after 11 time steps with total reward = 0.989 (streak 76).
# Episode 94 finished after 11 time steps with total reward = 0.989 (streak 77).
# Episode 95 finished after 11 time steps with total reward = 0.989 (streak 78).
# Episode 96 finished after 11 time steps with total reward = 0.989 (streak 79).
# Episode 97 finished after 11 time steps with total reward = 0.989 (streak 80).
# Episode 98 finished after 11 time steps with total reward = 0.989 (streak 81).
# Episode 99 finished after 11 time steps with total reward = 0.989 (streak 82).
# Episode 100 finished after 11 time steps with total reward = 0.989 (streak 83).
# Episode 101 finished after 11 time steps with total reward = 0.989 (streak 84).
# Episode 102 finished after 11 time steps with total reward = 0.989 (streak 85).
# Episode 103 finished after 11 time steps with total reward = 0.989 (streak 86).
# Episode 104 finished after 11 time steps with total reward = 0.989 (streak 87).
# Episode 105 finished after 11 time steps with total reward = 0.989 (streak 88).
# Episode 106 finished after 11 time steps with total reward = 0.989 (streak 89).
# Episode 107 finished after 11 time steps with total reward = 0.989 (streak 90).
# Episode 108 finished after 11 time steps with total reward = 0.989 (streak 91).
# Episode 109 finished after 11 time steps with total reward = 0.989 (streak 92).
# Episode 110 finished after 11 time steps with total reward = 0.989 (streak 93).
# Episode 111 finished after 11 time steps with total reward = 0.989 (streak 94).
# Episode 112 finished after 11 time steps with total reward = 0.989 (streak 95).
# Episode 113 finished after 11 time steps with total reward = 0.989 (streak 96).
# Episode 114 finished after 11 time steps with total reward = 0.989 (streak 97).
# Episode 115 finished after 11 time steps with total reward = 0.989 (streak 98).
# Episode 116 finished after 11 time steps with total reward = 0.989 (streak 99).
# Episode 117 finished after 11 time steps with total reward = 0.989 (streak 100).
# FINAL ACTION TABLE
#
# Action N table
#  [[ 8.04476853e-01 -6.98817943e-03 -7.91187047e-03 -7.28276617e-03
#   -3.39179178e-03 -3.22842136e-03]
#  [ 8.73147021e-01 -7.19296659e-03 -7.22770385e-03 -6.48702619e-03
#   -5.23963939e-03 -4.28075573e-03 -3.88766188e-03 -2.96512966e-03
#   -3.03695831e-03 -3.47459063e-03]
#  [ 8.84859410e-01  8.30725507e-01  7.78886360e-01 -6.56259517e-03
#   -6.46921325e-03 -4.82290561e-03 -4.62603679e-03  2.40574739e-01
#    8.31724128e-01  8.97743238e-01]
#  [ 8.94057541e-01 -5.75362758e-03 -5.90975284e-03 -5.11234887e-03
#   -4.95075261e-03 -5.44033535e-03 -4.47634821e-03 -8.00000000e-04
#   -1.75872000e-03  9.65130798e-01]
#  [ 9.04687040e-01 -5.85318802e-03 -4.64471548e-03 -5.76052298e-03
#   -5.33214760e-03 -5.96725732e-03 -5.28929427e-03 -9.92000000e-04
#   -1.87904000e-03  9.78109961e-01]
#  [ 9.14928598e-01 -5.73078974e-03 -4.26092010e-03 -3.23850813e-03
#   -3.55552893e-03 -4.27213240e-03 -5.42370597e-03 -1.62560000e-03
#   -1.58951298e-03  9.89000000e-01]
#  [ 9.24764025e-01  8.52057957e-01 -4.29327060e-03 -3.34229742e-03
#   -4.14162200e-03 -4.42940571e-03 -3.67991865e-03 -1.98395083e-03
#   -1.62870401e-03  9.56651958e-01]
#  [ 9.35626849e-01  9.21498304e-01 -4.30735000e-03 -2.75080847e-03
#   -2.38085120e-03 -2.60020429e-03 -4.50993714e-03 -2.88973130e-03
#    3.59919812e-01  9.45572838e-01]
#  [ 9.46088495e-01  9.67306584e-01 -4.48521002e-03 -3.68430122e-03
#   -3.53122525e-03 -3.93650996e-03  2.87742329e-01 -2.67243725e-03
#    9.52337740e-01  7.84665600e-01]
#  [ 7.83149656e-01  9.67328879e-01 -1.97288960e-03 -2.73323508e-03
#   -2.41265869e-03 -4.09346361e-03  2.87681350e-01  2.96331257e-01
#    9.56595445e-01  0.00000000e+00]]

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"learning_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [learning_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Learning Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Learning Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(learning_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"learning_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (127,)
# explore_rate Shape:  (127,)
# learning_rate Shape:  (127,)
# num_streaks Shape:  (127,)
# length_episode Shape:  (127,)
