# %% [markdown]
# # $$ Monte Carlo - First Visit - VFA $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os
from collections import defaultdict

# imports from project
from utils.plotting import plot_line_graphs_overlayed
from utils.file_management import create_folder_structure
from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","MC_First_Visit_VFA")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\results\\MC_First_Visit_VFA'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 300
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99

'''
CREATING RESULTS SAVING FOLDERS
'''
SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #Defining Feature Vector
    X = np.zeros((MAZE_SIZE[0]*MAZE_SIZE[1] , MAZE_SIZE[0]*MAZE_SIZE[1], 4))

    X[:,:,0] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 0
    X[:,:,1] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 1
    X[:,:,2] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 2
    X[:,:,3] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 3


    #Defining q_hat (oraculo)
    q_hat = defaultdict(lambda: np.zeros(env.action_space.n))
    
    #Defining wights
    weights = np.zeros(MAZE_SIZE[0]*MAZE_SIZE[1])

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the related par ameters
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    #Initializain num streaks
    num_streaks= 0


    for episode in range(NUM_EPISODES):
        # Episode Reinitialization
        total_reward = 0
        G_t = 0

        # Sample k-th episode (sk,1, ak,1, rk,1, sk,2, . . . , sk,T ) given πk
        obv = env.reset()
        state = state_to_bucket(obv)
        episode_array = []
        for t in range(MAX_T):
            action = epsilon_greedy_police(state, explore_rate,q_hat)
            obv, reward, done, _ = env.step(action)
            next_state = state_to_bucket(obv)
            total_reward += reward
            episode_array.append((state, action, reward)) # tuple transforma array([0,0]) em (0,0)

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()


            if done:
                print(f"Episode {episode} finished after {t} time steps with total reward = {total_reward} (streak {num_streaks}).")

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print(f"Episode {episode} timed out at {t} with total reward = {total_reward}.")

            state = next_state
        
        # Find all states the we've visited in this episode
        # We convert each state to a tuple so that we can use it as a dict key
        sa_in_episode = set([(tuple(x[0]), x[1]) for x in episode_array])
        for s, a in sa_in_episode:
            sa_pair = (s, a)
            # Find the first occurance of the (state, action) pair in the episode
            first_occurence_idx = next(i for i,x in enumerate(episode_array) if x[0] == s and x[1] == a)

            # Sum up all rewards since the first occurance
            G_t = sum([x[2]*(discount_factor**i) for i,x in enumerate(episode_array[first_occurence_idx:])])
            # Calculate average return for this state over all sampled episodes
            weights += (G_t - np.dot( X[:,MAZE_SIZE[0]*s[0]+s[1], a], weights) * X[:,MAZE_SIZE[0]*s[0]+s[1], a])
                        
            q_hat[s][a] += np.dot( X[:,MAZE_SIZE[0]*s[0]+s[1], a], weights)


        # Appending Episode values to the list
        reward_episode_list.append(total_reward)
        explore_rate_episode_list.append(explore_rate)
        num_streaks_episode_list.append(num_streaks)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)


    return (q_hat,np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def epsilon_greedy_police(state, explore_rate,q_hat):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_hat[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
Q,reward_episode_array,explore_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# Episode 0 finished after 1999 time steps with total reward = -7.999999999999562 (streak 0).
# Episode 1 finished after 1280 time steps with total reward = -4.119999999999879 (streak 0).
# Episode 2 finished after 418 time steps with total reward = -0.6720000000000013 (streak 0).
# Episode 3 finished after 231 time steps with total reward = 0.07599999999999929 (streak 0).
# Episode 4 finished after 133 time steps with total reward = 0.46799999999999964 (streak 0).
# Episode 5 finished after 103 time steps with total reward = 0.5879999999999996 (streak 0).
# Episode 6 finished after 474 time steps with total reward = -0.8960000000000015 (streak 0).
# Episode 7 finished after 66 time steps with total reward = 0.7359999999999998 (streak 0).
# Episode 8 finished after 281 time steps with total reward = -0.12400000000000078 (streak 0).
# Episode 9 finished after 352 time steps with total reward = -0.40800000000000103 (streak 0).
# Episode 10 finished after 63 time steps with total reward = 0.7479999999999998 (streak 0).
# Episode 11 finished after 64 time steps with total reward = 0.7439999999999998 (streak 0).
# Episode 12 finished after 22 time steps with total reward = 0.9119999999999999 (streak 0).
# Episode 13 finished after 29 time steps with total reward = 0.8839999999999999 (streak 1).
# Episode 14 finished after 24 time steps with total reward = 0.9039999999999999 (streak 0).
# Episode 15 finished after 16 time steps with total reward = 0.9359999999999999 (streak 1).
# Episode 16 finished after 17 time steps with total reward = 0.9319999999999999 (streak 2).
# Episode 17 finished after 14 time steps with total reward = 0.944 (streak 3).
# Episode 18 finished after 15 time steps with total reward = 0.94 (streak 4).
# Episode 19 finished after 15 time steps with total reward = 0.94 (streak 5).
# Episode 20 finished after 14 time steps with total reward = 0.944 (streak 6).
# Episode 21 finished after 13 time steps with total reward = 0.948 (streak 7).
# Episode 22 finished after 14 time steps with total reward = 0.944 (streak 8).
# Episode 23 finished after 13 time steps with total reward = 0.948 (streak 9).
# Episode 24 finished after 13 time steps with total reward = 0.948 (streak 10).
# Episode 25 finished after 13 time steps with total reward = 0.948 (streak 11).
# Episode 26 finished after 13 time steps with total reward = 0.948 (streak 12).
# Episode 27 finished after 13 time steps with total reward = 0.948 (streak 13).
# Episode 28 finished after 13 time steps with total reward = 0.948 (streak 14).
# Episode 29 finished after 13 time steps with total reward = 0.948 (streak 15).
# Episode 30 finished after 13 time steps with total reward = 0.948 (streak 16).
# Episode 31 finished after 13 time steps with total reward = 0.948 (streak 17).
# Episode 32 finished after 13 time steps with total reward = 0.948 (streak 18).
# Episode 33 finished after 13 time steps with total reward = 0.948 (streak 19).
# Episode 34 finished after 13 time steps with total reward = 0.948 (streak 20).
# Episode 35 finished after 13 time steps with total reward = 0.948 (streak 21).
# Episode 36 finished after 13 time steps with total reward = 0.948 (streak 22).
# Episode 37 finished after 13 time steps with total reward = 0.948 (streak 23).
# Episode 38 finished after 13 time steps with total reward = 0.948 (streak 24).
# Episode 39 finished after 13 time steps with total reward = 0.948 (streak 25).
# Episode 40 finished after 13 time steps with total reward = 0.948 (streak 26).
# Episode 41 finished after 13 time steps with total reward = 0.948 (streak 27).
# Episode 42 finished after 13 time steps with total reward = 0.948 (streak 28).
# Episode 43 finished after 13 time steps with total reward = 0.948 (streak 29).
# Episode 44 finished after 13 time steps with total reward = 0.948 (streak 30).
# Episode 45 finished after 13 time steps with total reward = 0.948 (streak 31).
# Episode 46 finished after 13 time steps with total reward = 0.948 (streak 32).
# Episode 47 finished after 13 time steps with total reward = 0.948 (streak 33).
# Episode 48 finished after 13 time steps with total reward = 0.948 (streak 34).
# Episode 49 finished after 13 time steps with total reward = 0.948 (streak 35).
# Episode 50 finished after 13 time steps with total reward = 0.948 (streak 36).
# Episode 51 finished after 15 time steps with total reward = 0.94 (streak 37).
# Episode 52 finished after 13 time steps with total reward = 0.948 (streak 38).
# Episode 53 finished after 13 time steps with total reward = 0.948 (streak 39).
# Episode 54 finished after 13 time steps with total reward = 0.948 (streak 40).
# Episode 55 finished after 13 time steps with total reward = 0.948 (streak 41).
# Episode 56 finished after 13 time steps with total reward = 0.948 (streak 42).
# Episode 57 finished after 13 time steps with total reward = 0.948 (streak 43).
# Episode 58 finished after 13 time steps with total reward = 0.948 (streak 44).
# Episode 59 finished after 13 time steps with total reward = 0.948 (streak 45).
# Episode 60 finished after 13 time steps with total reward = 0.948 (streak 46).
# Episode 61 finished after 13 time steps with total reward = 0.948 (streak 47).
# Episode 62 finished after 13 time steps with total reward = 0.948 (streak 48).
# Episode 63 finished after 13 time steps with total reward = 0.948 (streak 49).
# Episode 64 finished after 13 time steps with total reward = 0.948 (streak 50).
# Episode 65 finished after 13 time steps with total reward = 0.948 (streak 51).
# Episode 66 finished after 13 time steps with total reward = 0.948 (streak 52).
# Episode 67 finished after 13 time steps with total reward = 0.948 (streak 53).
# Episode 68 finished after 13 time steps with total reward = 0.948 (streak 54).
# Episode 69 finished after 13 time steps with total reward = 0.948 (streak 55).
# Episode 70 finished after 13 time steps with total reward = 0.948 (streak 56).
# Episode 71 finished after 13 time steps with total reward = 0.948 (streak 57).
# Episode 72 finished after 13 time steps with total reward = 0.948 (streak 58).
# Episode 73 finished after 13 time steps with total reward = 0.948 (streak 59).
# Episode 74 finished after 13 time steps with total reward = 0.948 (streak 60).
# Episode 75 finished after 13 time steps with total reward = 0.948 (streak 61).
# Episode 76 finished after 13 time steps with total reward = 0.948 (streak 62).
# Episode 77 finished after 13 time steps with total reward = 0.948 (streak 63).
# Episode 78 finished after 13 time steps with total reward = 0.948 (streak 64).
# Episode 79 finished after 13 time steps with total reward = 0.948 (streak 65).
# Episode 80 finished after 13 time steps with total reward = 0.948 (streak 66).
# Episode 81 finished after 13 time steps with total reward = 0.948 (streak 67).
# Episode 82 finished after 13 time steps with total reward = 0.948 (streak 68).
# Episode 83 finished after 13 time steps with total reward = 0.948 (streak 69).
# Episode 84 finished after 13 time steps with total reward = 0.948 (streak 70).
# Episode 85 finished after 13 time steps with total reward = 0.948 (streak 71).
# Episode 86 finished after 13 time steps with total reward = 0.948 (streak 72).
# Episode 87 finished after 13 time steps with total reward = 0.948 (streak 73).
# Episode 88 finished after 13 time steps with total reward = 0.948 (streak 74).
# Episode 89 finished after 13 time steps with total reward = 0.948 (streak 75).
# Episode 90 finished after 13 time steps with total reward = 0.948 (streak 76).
# Episode 91 finished after 13 time steps with total reward = 0.948 (streak 77).
# Episode 92 finished after 13 time steps with total reward = 0.948 (streak 78).
# Episode 93 finished after 13 time steps with total reward = 0.948 (streak 79).
# Episode 94 finished after 13 time steps with total reward = 0.948 (streak 80).
# Episode 95 finished after 13 time steps with total reward = 0.948 (streak 81).
# Episode 96 finished after 13 time steps with total reward = 0.948 (streak 82).
# Episode 97 finished after 13 time steps with total reward = 0.948 (streak 83).
# Episode 98 finished after 13 time steps with total reward = 0.948 (streak 84).
# Episode 99 finished after 13 time steps with total reward = 0.948 (streak 85).
# Episode 100 finished after 13 time steps with total reward = 0.948 (streak 86).
# Episode 101 finished after 13 time steps with total reward = 0.948 (streak 87).
# Episode 102 finished after 13 time steps with total reward = 0.948 (streak 88).
# Episode 103 finished after 13 time steps with total reward = 0.948 (streak 89).
# Episode 104 finished after 13 time steps with total reward = 0.948 (streak 90).
# Episode 105 finished after 13 time steps with total reward = 0.948 (streak 91).
# Episode 106 finished after 13 time steps with total reward = 0.948 (streak 92).
# Episode 107 finished after 13 time steps with total reward = 0.948 (streak 93).
# Episode 108 finished after 13 time steps with total reward = 0.948 (streak 94).
# Episode 109 finished after 13 time steps with total reward = 0.948 (streak 95).
# Episode 110 finished after 13 time steps with total reward = 0.948 (streak 96).
# Episode 111 finished after 13 time steps with total reward = 0.948 (streak 97).
# Episode 112 finished after 13 time steps with total reward = 0.948 (streak 98).
# Episode 113 finished after 13 time steps with total reward = 0.948 (streak 99).
# Episode 114 finished after 13 time steps with total reward = 0.948 (streak 100).

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)



graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (115,)
# explore_rate Shape:  (115,)
# num_streaks Shape:  (115,)
# length_episode Shape:  (115,)

# %% [markdown]
# ## Value Function

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

grid = np.zeros((5,5))
    
for i in range (5):
    for j in range (5):
        grid[i,j] = np.argmax(Q[i,j])
        

blue_patch = mpatches.Patch(color='blue', label='Azul - Baixo')
green_patch = mpatches.Patch(color='green', label='Verde - Direita')
yellow_patch = mpatches.Patch(color='yellow', label='Amarelo - Esquerda')
purple_patch = mpatches.Patch(color='purple', label='Roxo - Cima')

plt.legend(handles=[blue_patch,green_patch,yellow_patch,purple_patch])


ax.legend(loc="upper right")
ax.set_xlabel("X",fontsize = 10)
ax.set_ylabel("Y",fontsize = 10)
ax.set_title("Mapa de direções",fontsize = 20)
ax.figure.set_size_inches(10,10)
fig.tight_layout()
plt.imshow(grid.T)  
plt.savefig(f"{SAVING_RESULTS_IMAGE_FODLER}/directions_map")
plt.show()
plt.clf()
# Out:
# No handles with labels found to put in legend.
