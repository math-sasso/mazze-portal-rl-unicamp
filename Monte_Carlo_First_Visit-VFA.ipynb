# %% [markdown]
# # $$ Monte Carlo - First Visit - VFA $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os
from collections import defaultdict

# imports from project
from utils.plotting import plot_line_graphs_overlayed
from utils.file_management import create_folder_structure
from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","MC_First_Visit_VFA")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\results\\MC_First_Visit_LFA'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 300
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99

'''
CREATING RESULTS SAVING FOLDERS
'''
SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #Defining Feature Vector
    X = np.zeros((MAZE_SIZE[0]*MAZE_SIZE[1] , MAZE_SIZE[0]*MAZE_SIZE[1], 4))

    X[:,:,0] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 0
    X[:,:,1] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 1
    X[:,:,2] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 2
    X[:,:,3] = np.identity(MAZE_SIZE[0]*MAZE_SIZE[1]) # Vetor de estados para ação 3


    #Defining q_table
    q_hat = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
    
    #Defining wights
    weights = np.zeros(MAZE_SIZE[0]*MAZE_SIZE[1])

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the related parameters
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    #Initializain num streaks
    num_streaks= 0


    for episode in range(NUM_EPISODES):
        # Episode Reinitialization
        total_reward = 0
        G_t = 0

        # Sample k-th episode (sk,1, ak,1, rk,1, sk,2, . . . , sk,T ) given πk
        obv = env.reset()
        state = state_to_bucket(obv)
        episode_array = []
        for t in range(MAX_T):
            action = epsilon_greedy_police(state, explore_rate,q_hat)
            obv, reward, done, _ = env.step(action)
            next_state = state_to_bucket(obv)
            total_reward += reward
            episode_array.append((state, action, reward)) # tuple transforma array([0,0]) em (0,0)

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()


            if done:
                print(f"Episode {episode} finished after {t} time steps with total reward = {total_reward} (streak {num_streaks}).")

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print(f"Episode {episode} timed out at {t} with total reward = {total_reward}.")

            state = next_state
        
        # Find all states the we've visited in this episode
        # We convert each state to a tuple so that we can use it as a dict key
        sa_in_episode = set([(tuple(x[0]), x[1]) for x in episode_array])
        for s, a in sa_in_episode:
            sa_pair = (s, a)
            # Find the first occurance of the (state, action) pair in the episode
            first_occurence_idx = next(i for i,x in enumerate(episode_array) if x[0] == s and x[1] == a)

            # Sum up all rewards since the first occurance
            G_t = sum([x[2]*(discount_factor**i) for i,x in enumerate(episode_array[first_occurence_idx:])])
            # Calculate average return for this state over all sampled episodes
            weights += (G_t - np.dot( X[:,MAZE_SIZE[0]*s[0]+s[1], a], weights) * X[:,MAZE_SIZE[0]*s[0]+s[1], a])
                        
            q_hat[(s) + (a,)] += np.dot( X[:,MAZE_SIZE[0]*s[0]+s[1], a], weights)


        # Appending Episode values to the list
        reward_episode_list.append(total_reward)
        explore_rate_episode_list.append(explore_rate)
        num_streaks_episode_list.append(num_streaks)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)


    return (np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def epsilon_greedy_police(state, explore_rate,q_hat):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_hat[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
reward_episode_array,explore_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# Episode 0 finished after 693 time steps with total reward = 0.3069999999999995 (streak 0).
# Episode 1 finished after 4653 time steps with total reward = -3.6529999999998886 (streak 0).
# Episode 2 finished after 1657 time steps with total reward = -0.6569999999999283 (streak 0).
# Episode 3 finished after 1119 time steps with total reward = -0.11899999999998756 (streak 0).
# Episode 4 finished after 207 time steps with total reward = 0.7929999999999998 (streak 0).
# Episode 5 finished after 237 time steps with total reward = 0.7629999999999998 (streak 0).
# Episode 6 finished after 203 time steps with total reward = 0.7969999999999998 (streak 0).
# Episode 7 finished after 198 time steps with total reward = 0.8019999999999998 (streak 0).
# Episode 8 finished after 675 time steps with total reward = 0.3249999999999995 (streak 0).
# Episode 9 finished after 77 time steps with total reward = 0.9229999999999999 (streak 0).
# Episode 10 finished after 297 time steps with total reward = 0.7029999999999998 (streak 1).
# Episode 11 finished after 455 time steps with total reward = 0.5449999999999997 (streak 0).
# Episode 12 finished after 177 time steps with total reward = 0.8229999999999998 (streak 0).
# Episode 13 finished after 249 time steps with total reward = 0.7509999999999998 (streak 0).
# Episode 14 finished after 201 time steps with total reward = 0.7989999999999998 (streak 0).
# Episode 15 finished after 87 time steps with total reward = 0.9129999999999999 (streak 0).
# Episode 16 finished after 170 time steps with total reward = 0.8299999999999998 (streak 1).
# Episode 17 finished after 179 time steps with total reward = 0.8209999999999998 (streak 0).
# Episode 18 finished after 91 time steps with total reward = 0.9089999999999999 (streak 0).
# Episode 19 finished after 111 time steps with total reward = 0.8889999999999999 (streak 1).
# Episode 20 finished after 168 time steps with total reward = 0.8319999999999999 (streak 0).
# Episode 21 finished after 116 time steps with total reward = 0.8839999999999999 (streak 0).
# Episode 22 finished after 76 time steps with total reward = 0.9239999999999999 (streak 0).
# Episode 23 finished after 123 time steps with total reward = 0.8769999999999999 (streak 1).
# Episode 24 finished after 136 time steps with total reward = 0.8639999999999999 (streak 0).
# Episode 25 finished after 104 time steps with total reward = 0.8959999999999999 (streak 0).
# Episode 26 finished after 52 time steps with total reward = 0.948 (streak 0).
# Episode 27 finished after 124 time steps with total reward = 0.8759999999999999 (streak 1).
# Episode 28 finished after 43 time steps with total reward = 0.957 (streak 0).
# Episode 29 finished after 60 time steps with total reward = 0.94 (streak 1).
# Episode 30 finished after 82 time steps with total reward = 0.9179999999999999 (streak 2).
# Episode 31 finished after 78 time steps with total reward = 0.9219999999999999 (streak 3).
# Episode 32 finished after 35 time steps with total reward = 0.965 (streak 4).
# Episode 33 finished after 39 time steps with total reward = 0.961 (streak 5).
# Episode 34 finished after 45 time steps with total reward = 0.955 (streak 6).
# Episode 35 finished after 77 time steps with total reward = 0.9229999999999999 (streak 7).
# Episode 36 finished after 47 time steps with total reward = 0.953 (streak 8).
# Episode 37 finished after 36 time steps with total reward = 0.964 (streak 9).
# Episode 38 finished after 78 time steps with total reward = 0.9219999999999999 (streak 10).
# Episode 39 finished after 61 time steps with total reward = 0.939 (streak 11).
# Episode 40 finished after 47 time steps with total reward = 0.953 (streak 12).
# Episode 41 finished after 33 time steps with total reward = 0.967 (streak 13).
# Episode 42 finished after 78 time steps with total reward = 0.9219999999999999 (streak 14).
# Episode 43 finished after 41 time steps with total reward = 0.959 (streak 15).
# Episode 44 finished after 58 time steps with total reward = 0.942 (streak 16).
# Episode 45 finished after 28 time steps with total reward = 0.972 (streak 17).
# Episode 46 finished after 34 time steps with total reward = 0.966 (streak 18).
# Episode 47 finished after 33 time steps with total reward = 0.967 (streak 19).
# Episode 48 finished after 30 time steps with total reward = 0.97 (streak 20).
# Episode 49 finished after 37 time steps with total reward = 0.963 (streak 21).
# Episode 50 finished after 32 time steps with total reward = 0.968 (streak 22).
# Episode 51 finished after 27 time steps with total reward = 0.973 (streak 23).
# Episode 52 finished after 47 time steps with total reward = 0.953 (streak 24).
# Episode 53 finished after 40 time steps with total reward = 0.96 (streak 25).
# Episode 54 finished after 30 time steps with total reward = 0.97 (streak 26).
# Episode 55 finished after 32 time steps with total reward = 0.968 (streak 27).
# Episode 56 finished after 31 time steps with total reward = 0.969 (streak 28).
# Episode 57 finished after 32 time steps with total reward = 0.968 (streak 29).
# Episode 58 finished after 29 time steps with total reward = 0.971 (streak 30).
# Episode 59 finished after 34 time steps with total reward = 0.966 (streak 31).
# Episode 60 finished after 48 time steps with total reward = 0.952 (streak 32).
# Episode 61 finished after 33 time steps with total reward = 0.967 (streak 33).
# Episode 62 finished after 26 time steps with total reward = 0.974 (streak 34).
# Episode 63 finished after 46 time steps with total reward = 0.954 (streak 35).
# Episode 64 finished after 31 time steps with total reward = 0.969 (streak 36).
# Episode 65 finished after 29 time steps with total reward = 0.971 (streak 37).
# Episode 66 finished after 35 time steps with total reward = 0.965 (streak 38).
# Episode 67 finished after 27 time steps with total reward = 0.973 (streak 39).
# Episode 68 finished after 30 time steps with total reward = 0.97 (streak 40).
# Episode 69 finished after 25 time steps with total reward = 0.975 (streak 41).
# Episode 70 finished after 27 time steps with total reward = 0.973 (streak 42).
# Episode 71 finished after 24 time steps with total reward = 0.976 (streak 43).
# Episode 72 finished after 25 time steps with total reward = 0.975 (streak 44).
# Episode 73 finished after 34 time steps with total reward = 0.966 (streak 45).
# Episode 74 finished after 33 time steps with total reward = 0.967 (streak 46).
# Episode 75 finished after 29 time steps with total reward = 0.971 (streak 47).
# Episode 76 finished after 27 time steps with total reward = 0.973 (streak 48).
# Episode 77 finished after 26 time steps with total reward = 0.974 (streak 49).
# Episode 78 finished after 24 time steps with total reward = 0.976 (streak 50).
# Episode 79 finished after 23 time steps with total reward = 0.977 (streak 51).
# Episode 80 finished after 28 time steps with total reward = 0.972 (streak 52).
# Episode 81 finished after 28 time steps with total reward = 0.972 (streak 53).
# Episode 82 finished after 25 time steps with total reward = 0.975 (streak 54).
# Episode 83 finished after 24 time steps with total reward = 0.976 (streak 55).
# Episode 84 finished after 23 time steps with total reward = 0.977 (streak 56).
# Episode 85 finished after 24 time steps with total reward = 0.976 (streak 57).
# Episode 86 finished after 22 time steps with total reward = 0.978 (streak 58).
# Episode 87 finished after 63 time steps with total reward = 0.9369999999999999 (streak 59).
# Episode 88 finished after 23 time steps with total reward = 0.977 (streak 60).
# Episode 89 finished after 25 time steps with total reward = 0.975 (streak 61).
# Episode 90 finished after 23 time steps with total reward = 0.977 (streak 62).
# Episode 91 finished after 24 time steps with total reward = 0.976 (streak 63).
# Episode 92 finished after 23 time steps with total reward = 0.977 (streak 64).
# Episode 93 finished after 25 time steps with total reward = 0.975 (streak 65).
# Episode 94 finished after 23 time steps with total reward = 0.977 (streak 66).
# Episode 95 finished after 23 time steps with total reward = 0.977 (streak 67).
# Episode 96 finished after 23 time steps with total reward = 0.977 (streak 68).
# Episode 97 finished after 23 time steps with total reward = 0.977 (streak 69).
# Episode 98 finished after 23 time steps with total reward = 0.977 (streak 70).
# Episode 99 finished after 23 time steps with total reward = 0.977 (streak 71).
# Episode 100 finished after 23 time steps with total reward = 0.977 (streak 72).
# Episode 101 finished after 23 time steps with total reward = 0.977 (streak 73).
# Episode 102 finished after 23 time steps with total reward = 0.977 (streak 74).
# Episode 103 finished after 23 time steps with total reward = 0.977 (streak 75).
# Episode 104 finished after 23 time steps with total reward = 0.977 (streak 76).
# Episode 105 finished after 23 time steps with total reward = 0.977 (streak 77).
# Episode 106 finished after 23 time steps with total reward = 0.977 (streak 78).
# Episode 107 finished after 23 time steps with total reward = 0.977 (streak 79).
# Episode 108 finished after 23 time steps with total reward = 0.977 (streak 80).
# Episode 109 finished after 23 time steps with total reward = 0.977 (streak 81).
# Episode 110 finished after 23 time steps with total reward = 0.977 (streak 82).
# Episode 111 finished after 23 time steps with total reward = 0.977 (streak 83).
# Episode 112 finished after 23 time steps with total reward = 0.977 (streak 84).
# Episode 113 finished after 23 time steps with total reward = 0.977 (streak 85).
# Episode 114 finished after 25 time steps with total reward = 0.975 (streak 86).
# Episode 115 finished after 23 time steps with total reward = 0.977 (streak 87).
# Episode 116 finished after 23 time steps with total reward = 0.977 (streak 88).
# Episode 117 finished after 23 time steps with total reward = 0.977 (streak 89).
# Episode 118 finished after 23 time steps with total reward = 0.977 (streak 90).
# Episode 119 finished after 23 time steps with total reward = 0.977 (streak 91).
# Episode 120 finished after 23 time steps with total reward = 0.977 (streak 92).
# Episode 121 finished after 23 time steps with total reward = 0.977 (streak 93).
# Episode 122 finished after 23 time steps with total reward = 0.977 (streak 94).
# Episode 123 finished after 23 time steps with total reward = 0.977 (streak 95).
# Episode 124 finished after 23 time steps with total reward = 0.977 (streak 96).
# Episode 125 finished after 23 time steps with total reward = 0.977 (streak 97).
# Episode 126 finished after 23 time steps with total reward = 0.977 (streak 98).
# Episode 127 finished after 23 time steps with total reward = 0.977 (streak 99).
# Episode 128 finished after 23 time steps with total reward = 0.977 (streak 100).

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)



graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "MC-VFA: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (129,)
# explore_rate Shape:  (129,)
# num_streaks Shape:  (129,)
# length_episode Shape:  (129,)
