# %%
import sys
import numpy as np
import math
import random

# %%
import gym
import gym_maze

# %%
def simulate():
    
    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0) # alpha
    explore_rate = get_explore_rate(0)
    discount_factor = 0.99 #gamma
    eligibility_decay = 0.3
    epsilon = 1
    epsilon_decay = 0.999
    trace_decay = 0

    '''????????'''
    num_streaks = 0 

    # Render tha maze
    env.render()
    
    #q_table # inicializar ela aqui.
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)

    for episode in range(NUM_EPISODES):
        # Reset the environment
        obv = env.reset()
        
        # initialize Reward
        total_reward = 0
        
        # initialize episolon decay
        epsilon *= epsilon_decay

        # E(S,A) = 0
        E = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
        
        # Initialize state
        state = state_to_bucket(obv)
        
        # initialize action    # VERIFICAR SE SEGUE A POLITICA   
        action = select_action(state, explore_rate, q_table)
        
        for t in range(MAX_T):

            # Select an action
            next_action = select_action(state, explore_rate, q_table)
            
            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            next_state = state_to_bucket(obv)
            total_reward += reward
            
            # current_q
            current_q = q_table[state + (action,)] 
            
            # next_q
            next_q = q_table[next_state + (next_action,)]
            
            # TD - r + gamma * Q(S', A') - Q(S,A)
            TD = reward + (discount_factor * (next_q) - current_q )
            
            # E(S,A) - E(S,A) + 1
            E[state + (action,)] += 1
            
            #For all s E S, a E A(s)
            
            # aux_1
            aux_1 = learning_rate * TD * E
            
            # Q(S,A) - Q(S,A) + alpha * lamb * E
            q_table += aux_1
            
            
            # E(S, A) -  gama * trace_decay * E * delta * E(S,A)
            # delta = TD
            
            E = discount_factor * trace_decay * E
            
            #S - S'
            state = next_state
            
            # A - A'
            action = next_action
            
            # Print data
            if DEBUG_MODE == 2:
                print("\nEpisode = %d" % episode)
                print("t = %d" % t)
                print("Action: %d" % action)
                print("State: %s" % str(state))
                print("Reward: %f" % reward)
                print("Best Q: %f" % best_q)
                print("Explore rate: %f" % explore_rate)
                print("Learning rate: %f" % learning_rate)
                print("Streaks: %d" % num_streaks)
                print("")

            elif DEBUG_MODE == 1:
                if done or t >= MAX_T - 1:
                    print("\nEpisode = %d" % episode)
                    print("t = %d" % t)
                    print("Explore rate: %f" % explore_rate)
                    print("Learning rate: %f" % learning_rate)
                    print("Streaks: %d" % num_streaks)
                    print("Total reward: %f" % total_reward)
                    print("")

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print("Episode %d finished after %f time steps with total reward = %f (streak %d)."
                      % (episode, t, total_reward, num_streaks))

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print("Episode %d timed out at %d with total reward = %f."
                      % (episode, t, total_reward))

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)

# %%
def select_action(state, explore_rate, q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %%
def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %%
if __name__ == "__main__":

    # Initialize the "maze" environment
    env = gym.make("maze-random-10x10-plus-v0")

    '''
    Defining the environment related constants
    '''
    # Number of discrete states (bucket) per state dimension
    MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
    NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

    # Number of discrete actions
    NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
    # Bounds for each discrete state
    STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

    '''
    Learning related constants
    '''
    MIN_EXPLORE_RATE = 0.001
    MIN_LEARNING_RATE = 0.2
    DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

    '''
    Defining the simulation related constants
    '''
    NUM_EPISODES = 50000
    MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
    STREAK_TO_END = 100
    SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
    DEBUG_MODE = 0
    RENDER_MAZE = True
    ENABLE_RECORDING = True

    
    '''
    Begin simulation
    '''
    recording_folder = "/tmp/maze_q_learning"

    if ENABLE_RECORDING:
        #env.monitor.start(recording_folder, force=True)
        env = gym.wrappers.Monitor(env, "recording", force=True)
    simulate()

    if ENABLE_RECORDING:
        #env.monitor.close()
        env.close()
# Out:
# pygame 2.0.0 (SDL 2.0.12, python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Episode 0 finished after 566.000000 time steps with total reward = 0.434000 (streak 0).
# Episode 1 finished after 5404.000000 time steps with total reward = -4.404000 (streak 0).
# Episode 2 finished after 446.000000 time steps with total reward = 0.554000 (streak 0).
# Episode 3 finished after 1033.000000 time steps with total reward = -0.033000 (streak 0).
# Episode 4 finished after 143.000000 time steps with total reward = 0.857000 (streak 0).
# Episode 5 finished after 3284.000000 time steps with total reward = -2.284000 (streak 0).
# Episode 6 finished after 528.000000 time steps with total reward = 0.472000 (streak 0).
# Episode 7 finished after 216.000000 time steps with total reward = 0.784000 (streak 0).
# Episode 8 finished after 192.000000 time steps with total reward = 0.808000 (streak 0).
# Episode 9 finished after 347.000000 time steps with total reward = 0.653000 (streak 0).
# Episode 10 finished after 618.000000 time steps with total reward = 0.382000 (streak 0).
# Episode 11 finished after 359.000000 time steps with total reward = 0.641000 (streak 0).
# Episode 12 finished after 987.000000 time steps with total reward = 0.013000 (streak 0).
# Episode 13 finished after 279.000000 time steps with total reward = 0.721000 (streak 0).
# Episode 14 finished after 812.000000 time steps with total reward = 0.188000 (streak 0).
# Episode 15 finished after 1404.000000 time steps with total reward = -0.404000 (streak 0).
# Episode 16 finished after 257.000000 time steps with total reward = 0.743000 (streak 0).
# Episode 17 finished after 691.000000 time steps with total reward = 0.309000 (streak 0).
# Episode 18 finished after 333.000000 time steps with total reward = 0.667000 (streak 0).
# Episode 19 finished after 440.000000 time steps with total reward = 0.560000 (streak 0).
# Episode 20 finished after 352.000000 time steps with total reward = 0.648000 (streak 0).
# Episode 21 finished after 151.000000 time steps with total reward = 0.849000 (streak 0).
# Episode 22 finished after 355.000000 time steps with total reward = 0.645000 (streak 0).
# Episode 23 finished after 320.000000 time steps with total reward = 0.680000 (streak 0).
# Episode 24 finished after 98.000000 time steps with total reward = 0.902000 (streak 0).
# Episode 25 finished after 118.000000 time steps with total reward = 0.882000 (streak 1).
# Episode 26 finished after 862.000000 time steps with total reward = 0.138000 (streak 0).
# Episode 27 finished after 161.000000 time steps with total reward = 0.839000 (streak 0).
# Episode 28 finished after 154.000000 time steps with total reward = 0.846000 (streak 0).
# Episode 29 finished after 162.000000 time steps with total reward = 0.838000 (streak 0).
# Episode 30 finished after 100.000000 time steps with total reward = 0.900000 (streak 0).
# Episode 31 finished after 112.000000 time steps with total reward = 0.888000 (streak 1).
# Episode 32 finished after 119.000000 time steps with total reward = 0.881000 (streak 0).
# Episode 33 finished after 55.000000 time steps with total reward = 0.945000 (streak 0).
# Episode 34 finished after 417.000000 time steps with total reward = 0.583000 (streak 1).
# Episode 35 finished after 652.000000 time steps with total reward = 0.348000 (streak 0).
# Episode 36 finished after 262.000000 time steps with total reward = 0.738000 (streak 0).
# Episode 37 finished after 117.000000 time steps with total reward = 0.883000 (streak 0).
# Episode 38 finished after 81.000000 time steps with total reward = 0.919000 (streak 0).
# Episode 39 finished after 47.000000 time steps with total reward = 0.953000 (streak 1).
# Episode 40 finished after 59.000000 time steps with total reward = 0.941000 (streak 2).
# Episode 41 finished after 194.000000 time steps with total reward = 0.806000 (streak 3).
# Episode 42 finished after 33.000000 time steps with total reward = 0.967000 (streak 0).
# Episode 43 finished after 52.000000 time steps with total reward = 0.948000 (streak 1).
# Episode 44 finished after 176.000000 time steps with total reward = 0.824000 (streak 2).
# Episode 45 finished after 54.000000 time steps with total reward = 0.946000 (streak 0).
# Episode 46 finished after 79.000000 time steps with total reward = 0.921000 (streak 1).
# Episode 47 finished after 39.000000 time steps with total reward = 0.961000 (streak 2).
# Episode 48 finished after 79.000000 time steps with total reward = 0.921000 (streak 3).
# Episode 49 finished after 36.000000 time steps with total reward = 0.964000 (streak 4).
# Episode 50 finished after 108.000000 time steps with total reward = 0.892000 (streak 5).
# Episode 51 finished after 90.000000 time steps with total reward = 0.910000 (streak 0).
# Episode 52 finished after 63.000000 time steps with total reward = 0.937000 (streak 1).
# Episode 53 finished after 65.000000 time steps with total reward = 0.935000 (streak 2).
# Episode 54 finished after 58.000000 time steps with total reward = 0.942000 (streak 3).
# Episode 55 finished after 91.000000 time steps with total reward = 0.909000 (streak 4).
# Episode 56 finished after 47.000000 time steps with total reward = 0.953000 (streak 5).
# Episode 57 finished after 32.000000 time steps with total reward = 0.968000 (streak 6).
# Episode 58 finished after 53.000000 time steps with total reward = 0.947000 (streak 7).
# Episode 59 finished after 58.000000 time steps with total reward = 0.942000 (streak 8).
# Episode 60 finished after 39.000000 time steps with total reward = 0.961000 (streak 9).
# Episode 61 finished after 49.000000 time steps with total reward = 0.951000 (streak 10).
# Episode 62 finished after 48.000000 time steps with total reward = 0.952000 (streak 11).
# Episode 63 finished after 36.000000 time steps with total reward = 0.964000 (streak 12).
# Episode 64 finished after 34.000000 time steps with total reward = 0.966000 (streak 13).
# Episode 65 finished after 65.000000 time steps with total reward = 0.935000 (streak 14).
# Episode 66 finished after 62.000000 time steps with total reward = 0.938000 (streak 15).
# Episode 67 finished after 47.000000 time steps with total reward = 0.953000 (streak 16).
# Episode 68 finished after 41.000000 time steps with total reward = 0.959000 (streak 17).
# Episode 69 finished after 45.000000 time steps with total reward = 0.955000 (streak 18).
# Episode 70 finished after 35.000000 time steps with total reward = 0.965000 (streak 19).
# Episode 71 finished after 41.000000 time steps with total reward = 0.959000 (streak 20).
# Episode 72 finished after 40.000000 time steps with total reward = 0.960000 (streak 21).
# Episode 73 finished after 39.000000 time steps with total reward = 0.961000 (streak 22).
# Episode 74 finished after 95.000000 time steps with total reward = 0.905000 (streak 23).
# Episode 75 finished after 82.000000 time steps with total reward = 0.918000 (streak 24).
# Episode 76 finished after 40.000000 time steps with total reward = 0.960000 (streak 25).
# Episode 77 finished after 39.000000 time steps with total reward = 0.961000 (streak 26).
# Episode 78 finished after 36.000000 time steps with total reward = 0.964000 (streak 27).
# Episode 79 finished after 33.000000 time steps with total reward = 0.967000 (streak 28).
# Episode 80 finished after 31.000000 time steps with total reward = 0.969000 (streak 29).
# Episode 81 finished after 35.000000 time steps with total reward = 0.965000 (streak 30).
# Episode 82 finished after 31.000000 time steps with total reward = 0.969000 (streak 31).
# Episode 83 finished after 36.000000 time steps with total reward = 0.964000 (streak 32).
# Episode 84 finished after 67.000000 time steps with total reward = 0.933000 (streak 33).
# Episode 85 finished after 31.000000 time steps with total reward = 0.969000 (streak 34).
# Episode 86 finished after 34.000000 time steps with total reward = 0.966000 (streak 35).
# Episode 87 finished after 32.000000 time steps with total reward = 0.968000 (streak 36).
# Episode 88 finished after 33.000000 time steps with total reward = 0.967000 (streak 37).
# Episode 89 finished after 32.000000 time steps with total reward = 0.968000 (streak 38).
# Episode 90 finished after 43.000000 time steps with total reward = 0.957000 (streak 39).
# Episode 91 finished after 31.000000 time steps with total reward = 0.969000 (streak 40).
# Episode 92 finished after 35.000000 time steps with total reward = 0.965000 (streak 41).
# Episode 93 finished after 32.000000 time steps with total reward = 0.968000 (streak 42).
# Episode 94 finished after 31.000000 time steps with total reward = 0.969000 (streak 43).
# Episode 95 finished after 31.000000 time steps with total reward = 0.969000 (streak 44).
# Episode 96 finished after 31.000000 time steps with total reward = 0.969000 (streak 45).
# Episode 97 finished after 31.000000 time steps with total reward = 0.969000 (streak 46).
# Episode 98 finished after 31.000000 time steps with total reward = 0.969000 (streak 47).
# Episode 99 finished after 31.000000 time steps with total reward = 0.969000 (streak 48).
# Episode 100 finished after 31.000000 time steps with total reward = 0.969000 (streak 49).
# Episode 101 finished after 31.000000 time steps with total reward = 0.969000 (streak 50).
# Episode 102 finished after 31.000000 time steps with total reward = 0.969000 (streak 51).
# Episode 103 finished after 31.000000 time steps with total reward = 0.969000 (streak 52).
# Episode 104 finished after 32.000000 time steps with total reward = 0.968000 (streak 53).
# Episode 105 finished after 31.000000 time steps with total reward = 0.969000 (streak 54).
# Episode 106 finished after 31.000000 time steps with total reward = 0.969000 (streak 55).
# Episode 107 finished after 31.000000 time steps with total reward = 0.969000 (streak 56).
# Episode 108 finished after 31.000000 time steps with total reward = 0.969000 (streak 57).
# Episode 109 finished after 31.000000 time steps with total reward = 0.969000 (streak 58).
# Episode 110 finished after 31.000000 time steps with total reward = 0.969000 (streak 59).
# Episode 111 finished after 32.000000 time steps with total reward = 0.968000 (streak 60).
# Episode 112 finished after 31.000000 time steps with total reward = 0.969000 (streak 61).
# Episode 113 finished after 31.000000 time steps with total reward = 0.969000 (streak 62).
# Episode 114 finished after 31.000000 time steps with total reward = 0.969000 (streak 63).
# Episode 115 finished after 31.000000 time steps with total reward = 0.969000 (streak 64).
# Episode 116 finished after 31.000000 time steps with total reward = 0.969000 (streak 65).
# Episode 117 finished after 31.000000 time steps with total reward = 0.969000 (streak 66).
# Episode 118 finished after 31.000000 time steps with total reward = 0.969000 (streak 67).
# Episode 119 finished after 32.000000 time steps with total reward = 0.968000 (streak 68).
# Episode 120 finished after 31.000000 time steps with total reward = 0.969000 (streak 69).
# Episode 121 finished after 31.000000 time steps with total reward = 0.969000 (streak 70).
# Episode 122 finished after 31.000000 time steps with total reward = 0.969000 (streak 71).
# Episode 123 finished after 31.000000 time steps with total reward = 0.969000 (streak 72).
# Episode 124 finished after 31.000000 time steps with total reward = 0.969000 (streak 73).
# Episode 125 finished after 31.000000 time steps with total reward = 0.969000 (streak 74).
# Episode 126 finished after 31.000000 time steps with total reward = 0.969000 (streak 75).
# Episode 127 finished after 32.000000 time steps with total reward = 0.968000 (streak 76).
# Episode 128 finished after 31.000000 time steps with total reward = 0.969000 (streak 77).
# Episode 129 finished after 31.000000 time steps with total reward = 0.969000 (streak 78).
# Episode 130 finished after 31.000000 time steps with total reward = 0.969000 (streak 79).
# Episode 131 finished after 31.000000 time steps with total reward = 0.969000 (streak 80).
# Episode 132 finished after 31.000000 time steps with total reward = 0.969000 (streak 81).
# Episode 133 finished after 31.000000 time steps with total reward = 0.969000 (streak 82).
# Episode 134 finished after 31.000000 time steps with total reward = 0.969000 (streak 83).
# Episode 135 finished after 43.000000 time steps with total reward = 0.957000 (streak 84).
# Episode 136 finished after 31.000000 time steps with total reward = 0.969000 (streak 85).
# Episode 137 finished after 31.000000 time steps with total reward = 0.969000 (streak 86).
# Episode 138 finished after 30.000000 time steps with total reward = 0.970000 (streak 87).
# Episode 139 finished after 31.000000 time steps with total reward = 0.969000 (streak 88).
# Episode 140 finished after 31.000000 time steps with total reward = 0.969000 (streak 89).
# Episode 141 finished after 31.000000 time steps with total reward = 0.969000 (streak 90).
# Episode 142 finished after 32.000000 time steps with total reward = 0.968000 (streak 91).
# Episode 143 finished after 31.000000 time steps with total reward = 0.969000 (streak 92).
# Episode 144 finished after 31.000000 time steps with total reward = 0.969000 (streak 93).
# Episode 145 finished after 31.000000 time steps with total reward = 0.969000 (streak 94).
# Episode 146 finished after 31.000000 time steps with total reward = 0.969000 (streak 95).
# Episode 147 finished after 31.000000 time steps with total reward = 0.969000 (streak 96).
# Episode 148 finished after 31.000000 time steps with total reward = 0.969000 (streak 97).
# Episode 149 finished after 31.000000 time steps with total reward = 0.969000 (streak 98).
# Episode 150 finished after 32.000000 time steps with total reward = 0.968000 (streak 99).
# Episode 151 finished after 31.000000 time steps with total reward = 0.969000 (streak 100).
