# %% [markdown]
# # $$ Sarsa (\lambda)$$

# %% [markdown]
# ## Imports

# %%
# importsfrom libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os

# imports from project
from utils.plotting import plot_line_graphs_overlayed

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"result_graphs","SARSA_LAMBDA")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\result_graphs\\SARSA_LAMBDA'

# %% [markdown]
# Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-random-10x10-plus-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
LAMBDA_VAL = 0
MIN_EXPLORE_RATE = 0.001
MIN_LEARNING_RATE = 0.2
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 1000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
DEBUG_MODE = 0
RENDER_MAZE = False
ENABLE_RECORDING = False


'''
Begin simulation
'''
#recording_folder = "/tmp/maze_q_learning"

if ENABLE_RECORDING:
    #env.monitor.start(recording_folder, force=True)
    env = gym.wrappers.Monitor(env, "recording", force=True)
# Out:
# pygame 2.0.0 (SDL 2.0.12, python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float=0.99,
            eligibility_decay:float=0.3,
            epsilon:float= 1,
            epsilon_decay:float= 0.999,
            num_streaks:int= 0,
            trace_decay:int= 0):


    """Simulate Sarsa Algorythim .

    Args:
        discount_factor (float): gamma.
        eligibility_decay (float): .
        epsilon (float): gamma.
        epsilon_decay (float): gamma.
        num_streaks (float): How many times the problem was soved on the episode.
        trace_decay (float): gamma.


    Returns:
        (matplotlib.Axes): the axes object.
    """
    
    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    learning_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []



    #discount_factor = gamma

    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0) # alpha
    explore_rate = get_explore_rate(0)
     
    # Render tha maze
    env.render()
    
    #q_table # inicializar ela aqui.
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
    

    #Initializain num streaks
    num_streaks= 0

    for episode in range(NUM_EPISODES):

 
        # Reset the environment
        obv = env.reset()
        
        # initialize Reward
        total_reward = 0
        
        # initialize episolon decay
        epsilon *= epsilon_decay

        # E(S,A) = 0
        E = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
        
        # Initialize state
        state = state_to_bucket(obv)
        
        # initialize action    # VERIFICAR SE SEGUE A POLITICA   
        action = select_action(state, explore_rate, q_table)
        
        for t in range(MAX_T):

            # Select an action
            next_action = select_action(state, explore_rate, q_table)
            
            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            next_state = state_to_bucket(obv)
            total_reward += reward
            
            # current_q
            current_q = q_table[state + (action,)] 
            
            # next_q
            next_q = q_table[next_state + (next_action,)]
            
            # TD - r + gamma * Q(S', A') - Q(S,A)
            TD = reward + (discount_factor * (next_q) - current_q )
            
            # E(S,A) - E(S,A) + 1
            E[state + (action,)] += 1
            
            #For all s E S, a E A(s)
            
            # aux_1
            aux_1 = learning_rate * TD * E
            
            # Q(S,A) - Q(S,A) + alpha * lamb * E
            q_table += aux_1
            
            
            # E(S, A) -  gama * trace_decay * E * delta * E(S,A)
            # delta = TD
            
            E = discount_factor * trace_decay * E
            
            #S - S'
            state = next_state
            
            # A - A'
            action = next_action
            
            # Print data
            if DEBUG_MODE == 2:
                print("\nEpisode = %d" % episode)
                print("t = %d" % t)
                print("Action: %d" % action)
                print("State: %s" % str(state))
                print("Reward: %f" % reward)
                print("Best Q: %f" % best_q)
                print("Explore rate: %f" % explore_rate)
                print("Learning rate: %f" % learning_rate)
                print("Streaks: %d" % num_streaks)
                print("")

            elif DEBUG_MODE == 1:
                if done or t >= MAX_T - 1:
                    print("\nEpisode = %d" % episode)
                    print("t = %d" % t)
                    print("Explore rate: %f" % explore_rate)
                    print("Learning rate: %f" % learning_rate)
                    print("Streaks: %d" % num_streaks)
                    print("Total reward: %f" % total_reward)
                    print("")

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print("Episode %d finished after %f time steps with total reward = %f (streak %d)."
                      % (episode, t, total_reward, num_streaks))

                num_streaks_copy = num_streaks
                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print("Episode %d timed out at %d with total reward = %f."
                      % (episode, t, total_reward))

        

        
        reward_episode_list.append(action)
        explore_rate_episode_list.append(explore_rate)
        learning_rate_episode_list.append(learning_rate)
        num_streaks_episode_list.append(num_streaks_copy)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)

    
    print("FINAL ACTION TABLE \n")
    acts = ["N", "S", "E", "W"]
    for i in range(q_table.shape[2]):
        print(f"Action {acts[i]} table \n {q_table[:,:,i]}\n")

    return (np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(learning_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def select_action(state, explore_rate, q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE and LEARNING_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %%
def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## ?????

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
reward_episode_array,explore_rate_episode_array,learning_rate_episode_array,num_streaks_episode_array,length_episode_array = \
simulate(discount_factor=0.99,
        eligibility_decay=0.3,
        epsilon=1,
        epsilon_decay= 0.999,
        num_streaks= 0,
        trace_decay=LAMBDA_VAL)

                                                                                                    
if ENABLE_RECORDING:
    #env.monitor.close()
    env.close()
# Out:
# Episode 350 finished after 30.000000 time steps with total reward = 0.970000 (streak 24).
# Episode 351 finished after 30.000000 time steps with total reward = 0.970000 (streak 25).
# Episode 352 finished after 30.000000 time steps with total reward = 0.970000 (streak 26).
# Episode 353 finished after 30.000000 time steps with total reward = 0.970000 (streak 27).
# Episode 354 finished after 30.000000 time steps with total reward = 0.970000 (streak 28).
# Episode 355 finished after 30.000000 time steps with total reward = 0.970000 (streak 29).
# Episode 356 finished after 30.000000 time steps with total reward = 0.970000 (streak 30).
# Episode 357 finished after 30.000000 time steps with total reward = 0.970000 (streak 31).
# Episode 358 finished after 30.000000 time steps with total reward = 0.970000 (streak 32).
# Episode 359 finished after 30.000000 time steps with total reward = 0.970000 (streak 33).
# Episode 360 finished after 30.000000 time steps with total reward = 0.970000 (streak 34).
# Episode 361 finished after 30.000000 time steps with total reward = 0.970000 (streak 35).
# Episode 362 finished after 30.000000 time steps with total reward = 0.970000 (streak 36).
# Episode 363 finished after 30.000000 time steps with total reward = 0.970000 (streak 37).
# Episode 364 finished after 30.000000 time steps with total reward = 0.970000 (streak 38).
# Episode 365 finished after 30.000000 time steps with total reward = 0.970000 (streak 39).
# Episode 366 finished after 30.000000 time steps with total reward = 0.970000 (streak 40).
# Episode 367 finished after 30.000000 time steps with total reward = 0.970000 (streak 41).
# Episode 368 finished after 30.000000 time steps with total reward = 0.970000 (streak 42).
# Episode 369 finished after 30.000000 time steps with total reward = 0.970000 (streak 43).
# Episode 370 finished after 30.000000 time steps with total reward = 0.970000 (streak 44).
# Episode 371 finished after 30.000000 time steps with total reward = 0.970000 (streak 45).
# Episode 372 finished after 30.000000 time steps with total reward = 0.970000 (streak 46).
# Episode 373 finished after 30.000000 time steps with total reward = 0.970000 (streak 47).
# Episode 374 finished after 30.000000 time steps with total reward = 0.970000 (streak 48).
# Episode 375 finished after 30.000000 time steps with total reward = 0.970000 (streak 49).
# Episode 376 finished after 30.000000 time steps with total reward = 0.970000 (streak 50).
# Episode 377 finished after 30.000000 time steps with total reward = 0.970000 (streak 51).
# Episode 378 finished after 30.000000 time steps with total reward = 0.970000 (streak 52).
# Episode 379 finished after 30.000000 time steps with total reward = 0.970000 (streak 53).
# Episode 380 finished after 30.000000 time steps with total reward = 0.970000 (streak 54).
# Episode 381 finished after 30.000000 time steps with total reward = 0.970000 (streak 55).
# Episode 382 finished after 30.000000 time steps with total reward = 0.970000 (streak 56).
# Episode 383 finished after 30.000000 time steps with total reward = 0.970000 (streak 57).
# Episode 384 finished after 30.000000 time steps with total reward = 0.970000 (streak 58).
# Episode 385 finished after 30.000000 time steps with total reward = 0.970000 (streak 59).
# Episode 386 finished after 30.000000 time steps with total reward = 0.970000 (streak 60).
# Episode 387 finished after 30.000000 time steps with total reward = 0.970000 (streak 61).
# Episode 388 finished after 30.000000 time steps with total reward = 0.970000 (streak 62).
# Episode 389 finished after 30.000000 time steps with total reward = 0.970000 (streak 63).
# Episode 390 finished after 30.000000 time steps with total reward = 0.970000 (streak 64).
# Episode 391 finished after 30.000000 time steps with total reward = 0.970000 (streak 65).
# Episode 392 finished after 30.000000 time steps with total reward = 0.970000 (streak 66).
# Episode 393 finished after 30.000000 time steps with total reward = 0.970000 (streak 67).
# Episode 394 finished after 30.000000 time steps with total reward = 0.970000 (streak 68).
# Episode 395 finished after 117.000000 time steps with total reward = 0.883000 (streak 69).
# Episode 396 finished after 30.000000 time steps with total reward = 0.970000 (streak 0).
# Episode 397 finished after 42.000000 time steps with total reward = 0.958000 (streak 1).
# Episode 398 finished after 44.000000 time steps with total reward = 0.956000 (streak 2).
# Episode 399 finished after 39.000000 time steps with total reward = 0.961000 (streak 3).
# Episode 400 finished after 37.000000 time steps with total reward = 0.963000 (streak 4).
# Episode 401 finished after 38.000000 time steps with total reward = 0.962000 (streak 5).
# Episode 402 finished after 36.000000 time steps with total reward = 0.964000 (streak 6).
# Episode 403 finished after 34.000000 time steps with total reward = 0.966000 (streak 7).
# Episode 404 finished after 34.000000 time steps with total reward = 0.966000 (streak 8).
# Episode 405 finished after 33.000000 time steps with total reward = 0.967000 (streak 9).
# Episode 406 finished after 32.000000 time steps with total reward = 0.968000 (streak 10).
# Episode 407 finished after 32.000000 time steps with total reward = 0.968000 (streak 11).
# Episode 408 finished after 31.000000 time steps with total reward = 0.969000 (streak 12).
# Episode 409 finished after 30.000000 time steps with total reward = 0.970000 (streak 13).
# Episode 410 finished after 30.000000 time steps with total reward = 0.970000 (streak 14).
# Episode 411 finished after 30.000000 time steps with total reward = 0.970000 (streak 15).
# Episode 412 finished after 30.000000 time steps with total reward = 0.970000 (streak 16).
# Episode 413 finished after 31.000000 time steps with total reward = 0.969000 (streak 17).
# Episode 414 finished after 31.000000 time steps with total reward = 0.969000 (streak 18).
# Episode 415 finished after 31.000000 time steps with total reward = 0.969000 (streak 19).
# Episode 416 finished after 31.000000 time steps with total reward = 0.969000 (streak 20).
# Episode 417 finished after 32.000000 time steps with total reward = 0.968000 (streak 21).
# Episode 418 finished after 31.000000 time steps with total reward = 0.969000 (streak 22).
# Episode 419 finished after 34.000000 time steps with total reward = 0.966000 (streak 23).
# Episode 420 finished after 33.000000 time steps with total reward = 0.967000 (streak 24).
# Episode 421 finished after 32.000000 time steps with total reward = 0.968000 (streak 25).
# Episode 422 finished after 31.000000 time steps with total reward = 0.969000 (streak 26).
# Episode 423 finished after 32.000000 time steps with total reward = 0.968000 (streak 27).
# Episode 424 finished after 31.000000 time steps with total reward = 0.969000 (streak 28).
# Episode 425 finished after 31.000000 time steps with total reward = 0.969000 (streak 29).
# Episode 426 finished after 32.000000 time steps with total reward = 0.968000 (streak 30).
# Episode 427 finished after 32.000000 time steps with total reward = 0.968000 (streak 31).
# Episode 428 finished after 31.000000 time steps with total reward = 0.969000 (streak 32).
# Episode 429 finished after 32.000000 time steps with total reward = 0.968000 (streak 33).
# Episode 430 finished after 30.000000 time steps with total reward = 0.970000 (streak 34).
# Episode 431 finished after 41.000000 time steps with total reward = 0.959000 (streak 35).
# Episode 432 finished after 39.000000 time steps with total reward = 0.961000 (streak 36).
# Episode 433 finished after 35.000000 time steps with total reward = 0.965000 (streak 37).
# Episode 434 finished after 31.000000 time steps with total reward = 0.969000 (streak 38).
# Episode 435 finished after 33.000000 time steps with total reward = 0.967000 (streak 39).
# Episode 436 finished after 34.000000 time steps with total reward = 0.966000 (streak 40).
# Episode 437 finished after 32.000000 time steps with total reward = 0.968000 (streak 41).
# Episode 438 finished after 32.000000 time steps with total reward = 0.968000 (streak 42).
# Episode 439 finished after 31.000000 time steps with total reward = 0.969000 (streak 43).
# Episode 440 finished after 30.000000 time steps with total reward = 0.970000 (streak 44).
# Episode 441 finished after 31.000000 time steps with total reward = 0.969000 (streak 45).
# Episode 442 finished after 30.000000 time steps with total reward = 0.970000 (streak 46).
# Episode 443 finished after 30.000000 time steps with total reward = 0.970000 (streak 47).
# Episode 444 finished after 30.000000 time steps with total reward = 0.970000 (streak 48).
# Episode 445 finished after 30.000000 time steps with total reward = 0.970000 (streak 49).
# Episode 446 finished after 30.000000 time steps with total reward = 0.970000 (streak 50).
# Episode 447 finished after 30.000000 time steps with total reward = 0.970000 (streak 51).
# Episode 448 finished after 30.000000 time steps with total reward = 0.970000 (streak 52).
# Episode 449 finished after 30.000000 time steps with total reward = 0.970000 (streak 53).
# Episode 450 finished after 30.000000 time steps with total reward = 0.970000 (streak 54).
# Episode 451 finished after 96.000000 time steps with total reward = 0.904000 (streak 55).
# Episode 452 finished after 30.000000 time steps with total reward = 0.970000 (streak 56).
# Episode 453 finished after 39.000000 time steps with total reward = 0.961000 (streak 57).
# Episode 454 finished after 39.000000 time steps with total reward = 0.961000 (streak 58).
# Episode 455 finished after 36.000000 time steps with total reward = 0.964000 (streak 59).
# Episode 456 finished after 36.000000 time steps with total reward = 0.964000 (streak 60).
# Episode 457 finished after 35.000000 time steps with total reward = 0.965000 (streak 61).
# Episode 458 finished after 34.000000 time steps with total reward = 0.966000 (streak 62).
# Episode 459 finished after 33.000000 time steps with total reward = 0.967000 (streak 63).
# Episode 460 finished after 33.000000 time steps with total reward = 0.967000 (streak 64).
# Episode 461 finished after 32.000000 time steps with total reward = 0.968000 (streak 65).
# Episode 462 finished after 31.000000 time steps with total reward = 0.969000 (streak 66).
# Episode 463 finished after 31.000000 time steps with total reward = 0.969000 (streak 67).
# Episode 464 finished after 31.000000 time steps with total reward = 0.969000 (streak 68).
# Episode 465 finished after 30.000000 time steps with total reward = 0.970000 (streak 69).
# Episode 466 finished after 30.000000 time steps with total reward = 0.970000 (streak 70).
# Episode 467 finished after 30.000000 time steps with total reward = 0.970000 (streak 71).
# Episode 468 finished after 30.000000 time steps with total reward = 0.970000 (streak 72).
# Episode 469 finished after 30.000000 time steps with total reward = 0.970000 (streak 73).
# Episode 470 finished after 30.000000 time steps with total reward = 0.970000 (streak 74).
# Episode 471 finished after 31.000000 time steps with total reward = 0.969000 (streak 75).
# Episode 472 finished after 31.000000 time steps with total reward = 0.969000 (streak 76).
# Episode 473 finished after 30.000000 time steps with total reward = 0.970000 (streak 77).
# Episode 474 finished after 31.000000 time steps with total reward = 0.969000 (streak 78).
# Episode 475 finished after 31.000000 time steps with total reward = 0.969000 (streak 79).
# Episode 476 finished after 30.000000 time steps with total reward = 0.970000 (streak 80).
# Episode 477 finished after 31.000000 time steps with total reward = 0.969000 (streak 81).
# Episode 478 finished after 30.000000 time steps with total reward = 0.970000 (streak 82).
# Episode 479 finished after 30.000000 time steps with total reward = 0.970000 (streak 83).
# Episode 480 finished after 30.000000 time steps with total reward = 0.970000 (streak 84).
# Episode 481 finished after 30.000000 time steps with total reward = 0.970000 (streak 85).
# Episode 482 finished after 30.000000 time steps with total reward = 0.970000 (streak 86).
# Episode 483 finished after 30.000000 time steps with total reward = 0.970000 (streak 87).
# Episode 484 finished after 30.000000 time steps with total reward = 0.970000 (streak 88).
# Episode 485 finished after 30.000000 time steps with total reward = 0.970000 (streak 89).
# Episode 486 finished after 30.000000 time steps with total reward = 0.970000 (streak 90).
# Episode 487 finished after 30.000000 time steps with total reward = 0.970000 (streak 91).
# Episode 488 finished after 30.000000 time steps with total reward = 0.970000 (streak 92).
# Episode 489 finished after 30.000000 time steps with total reward = 0.970000 (streak 93).
# Episode 490 finished after 30.000000 time steps with total reward = 0.970000 (streak 94).
# Episode 491 finished after 30.000000 time steps with total reward = 0.970000 (streak 95).
# Episode 492 finished after 30.000000 time steps with total reward = 0.970000 (streak 96).
# Episode 493 finished after 30.000000 time steps with total reward = 0.970000 (streak 97).
# Episode 494 finished after 30.000000 time steps with total reward = 0.970000 (streak 98).
#    9.42706502e-01  0.00000000e+00]]
#
# Action W table
#  [[-1.42512780e-02 -1.57259586e-02  4.78957265e-03 -1.80336983e-02
#   -1.50810719e-02 -2.07296877e-02 -2.26150516e-02  9.48563143e-02
#   -2.19056229e-04 -4.15114386e-04]
#  [-1.95320702e-02  2.05484213e-02 -2.52951732e-04 -2.98055418e-02
#   -1.93961591e-02 -2.98008777e-02 -2.19428923e-02  9.14887486e-01
#    2.88983137e-02 -1.40585076e-02]
#  [-5.10950886e-03  1.36737567e-01  7.20710541e-01 -2.01722591e-02
#   -2.25330134e-02 -2.12706782e-02 -2.30727335e-02  9.03760734e-01
#    3.78976186e-02 -4.36846115e-03]
#  [-2.25062071e-02  2.18952092e-02  3.74745994e-02 -2.79827863e-02
#   -2.40567369e-02 -2.32479618e-02  7.74246514e-01  8.86861717e-01
#   -7.35413216e-03 -1.38526562e-02]
#  [ 9.54136394e-02 -1.91017753e-02 -1.95011151e-02 -2.65491763e-02
#   -2.52669292e-02 -2.07734872e-02 -1.02666692e-02 -8.81861350e-03
#   -1.39387454e-02 -5.18173477e-03]
#  [-2.05051805e-02 -1.70540495e-02 -1.86158073e-02 -2.51474804e-02
#   -2.55048681e-02 -2.11673267e-02 -1.06934619e-02 -7.59437770e-03
#   -8.12460612e-03  3.21580843e-02]
#  [-1.50089967e-02 -1.63461686e-02 -1.93314147e-02 -1.83801558e-02
#   -1.46678553e-02 -2.45500832e-02 -9.86107651e-03 -1.10622465e-02
#   -6.83127965e-03  1.44260183e-03]
#  [-1.29644951e-02 -1.31520438e-02 -1.36219529e-02 -1.64674796e-02
#   -1.92080765e-02  9.25271852e-01  2.70161944e-01  1.60220611e-01
#   -1.18432847e-02  3.20236968e-03]
#  [-1.38224005e-02 -1.11381143e-02 -1.01034203e-02  9.02718018e-01
#   -1.05473453e-02  6.01894566e-02  3.05659507e-01 -1.74566400e-03
#   -1.43360000e-03  1.45993125e-01]
#  [-6.50343191e-03  7.59862974e-03 -1.00173322e-02  8.89310844e-01
#    2.53166282e-02  4.40943849e-01  3.32749278e-01  8.84084029e-01
#    9.21441445e-01  0.00000000e+00]]

# %%
 
graph_saving_path = os.path.join(SAVING_RESULTS_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = [f"Lambda {LAMBDA_VAL}"],
                            title = "Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = [f"Lambda {LAMBDA_VAL}"],
                            title = "Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_FODLER,"learning_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [learning_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Learning Rate",
                            legends = [f"Lambda {LAMBDA_VAL}"],
                            title = "Learning Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = [f"Lambda {LAMBDA_VAL}"],
                            title = "Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = [f"Lambda {LAMBDA_VAL}"],
                            title = "Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)
# Out:
# module 'matplotlib.pyplot' has no attribute 'write_image'
# module 'matplotlib.pyplot' has no attribute 'write_image'
# module 'matplotlib.pyplot' has no attribute 'write_image'
# module 'matplotlib.pyplot' has no attribute 'write_image'
# module 'matplotlib.pyplot' has no attribute 'write_image'
