# %% [markdown]
# # $$ Q - Learning $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os

# imports from project
from utils.plotting import plot_line_graphs_overlayed
from utils.file_management import create_folder_structure
from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","Q_LEANING")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\results\\Q_LEANING'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-random-10x10-plus-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
MIN_LEARNING_RATE = 0.2
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 1000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
DEBUG_MODE = 0
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99

'''
CREATING RESULTS SAVING FOLDERS
'''
SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)
# Out:
# pygame 2.0.0 (SDL 2.0.12, python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(learning_rate_episode_list): Numpy array with the episodes learning rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    learning_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    # Initialize q_table
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)

    #Initializain num streaks
    num_streaks= 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)
        total_reward = 0

        for t in range(MAX_T):

            # Select an action
            action = select_action(state_0, explore_rate,q_table)

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)
            total_reward += reward

            # Update the Q based on the result
            best_q = np.amax(q_table[state])
            q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * (best_q) - q_table[state_0 + (action,)])

            # Setting up for the next iteration
            state_0 = state

            # Print data
            if DEBUG_MODE == 2:
                print("\nEpisode = %d" % episode)
                print("t = %d" % t)
                print("Action: %d" % action)
                print("State: %s" % str(state))
                print("Reward: %f" % reward)
                print("Best Q: %f" % best_q)
                print("Explore rate: %f" % explore_rate)
                print("Learning rate: %f" % learning_rate)
                print("Streaks: %d" % num_streaks)
                print("")

            elif DEBUG_MODE == 1:
                if done or t >= MAX_T - 1:
                    print("\nEpisode = %d" % episode)
                    print("t = %d" % t)
                    print("Explore rate: %f" % explore_rate)
                    print("Learning rate: %f" % learning_rate)
                    print("Streaks: %d" % num_streaks)
                    print("Total reward: %f" % total_reward)
                    print("")

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print("Episode %d finished after %f time steps with total reward = %f (streak %d)."
                      % (episode, t, total_reward, num_streaks))
                num_streaks_copy = num_streaks
                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print("Episode %d timed out at %d with total reward = %f."
                      % (episode, t, total_reward))

        # Appending Episode values to the list
        reward_episode_list.append(reward)
        explore_rate_episode_list.append(explore_rate)
        learning_rate_episode_list.append(learning_rate)
        num_streaks_episode_list.append(num_streaks_copy)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)


    print("FINAL ACTION TABLE \n")
    acts = ["N", "S", "E", "W"]
    for i in range(q_table.shape[2]):
        print(f"Action {acts[i]} table \n {q_table[:,:,i]}\n")

    return (np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(learning_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def select_action(state, explore_rate,q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE and LEARNING_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %%
def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
reward_episode_array,explore_rate_episode_array,learning_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# Episode 0 finished after 1537.000000 time steps with total reward = -0.537000 (streak 0).
# Episode 1 finished after 675.000000 time steps with total reward = 0.325000 (streak 0).
# Episode 2 finished after 722.000000 time steps with total reward = 0.278000 (streak 0).
# Episode 3 finished after 187.000000 time steps with total reward = 0.813000 (streak 0).
# Episode 4 finished after 456.000000 time steps with total reward = 0.544000 (streak 0).
# Episode 5 finished after 166.000000 time steps with total reward = 0.834000 (streak 0).
# Episode 6 finished after 167.000000 time steps with total reward = 0.833000 (streak 0).
# Episode 7 finished after 153.000000 time steps with total reward = 0.847000 (streak 0).
# Episode 8 finished after 545.000000 time steps with total reward = 0.455000 (streak 0).
# Episode 9 finished after 149.000000 time steps with total reward = 0.851000 (streak 0).
# Episode 10 finished after 185.000000 time steps with total reward = 0.815000 (streak 0).
# Episode 11 finished after 69.000000 time steps with total reward = 0.931000 (streak 0).
# Episode 12 finished after 96.000000 time steps with total reward = 0.904000 (streak 1).
# Episode 13 finished after 232.000000 time steps with total reward = 0.768000 (streak 2).
# Episode 14 finished after 83.000000 time steps with total reward = 0.917000 (streak 0).
# Episode 15 finished after 83.000000 time steps with total reward = 0.917000 (streak 1).
# Episode 16 finished after 161.000000 time steps with total reward = 0.839000 (streak 2).
# Episode 17 finished after 112.000000 time steps with total reward = 0.888000 (streak 0).
# Episode 18 finished after 95.000000 time steps with total reward = 0.905000 (streak 0).
# Episode 19 finished after 65.000000 time steps with total reward = 0.935000 (streak 1).
# Episode 20 finished after 59.000000 time steps with total reward = 0.941000 (streak 2).
# Episode 21 finished after 54.000000 time steps with total reward = 0.946000 (streak 3).
# Episode 22 finished after 37.000000 time steps with total reward = 0.963000 (streak 4).
# Episode 23 finished after 81.000000 time steps with total reward = 0.919000 (streak 5).
# Episode 24 finished after 65.000000 time steps with total reward = 0.935000 (streak 6).
# Episode 25 finished after 44.000000 time steps with total reward = 0.956000 (streak 7).
# Episode 26 finished after 22.000000 time steps with total reward = 0.978000 (streak 8).
# Episode 27 finished after 42.000000 time steps with total reward = 0.958000 (streak 9).
# Episode 28 finished after 56.000000 time steps with total reward = 0.944000 (streak 10).
# Episode 29 finished after 21.000000 time steps with total reward = 0.979000 (streak 11).
# Episode 30 finished after 24.000000 time steps with total reward = 0.976000 (streak 12).
# Episode 31 finished after 42.000000 time steps with total reward = 0.958000 (streak 13).
# Episode 32 finished after 26.000000 time steps with total reward = 0.974000 (streak 14).
# Episode 33 finished after 49.000000 time steps with total reward = 0.951000 (streak 15).
# Episode 34 finished after 27.000000 time steps with total reward = 0.973000 (streak 16).
# Episode 35 finished after 31.000000 time steps with total reward = 0.969000 (streak 17).
# Episode 36 finished after 23.000000 time steps with total reward = 0.977000 (streak 18).
# Episode 37 finished after 25.000000 time steps with total reward = 0.975000 (streak 19).
# Episode 38 finished after 23.000000 time steps with total reward = 0.977000 (streak 20).
# Episode 39 finished after 19.000000 time steps with total reward = 0.981000 (streak 21).
# Episode 40 finished after 22.000000 time steps with total reward = 0.978000 (streak 22).
# Episode 41 finished after 27.000000 time steps with total reward = 0.973000 (streak 23).
# Episode 42 finished after 26.000000 time steps with total reward = 0.974000 (streak 24).
# Episode 43 finished after 17.000000 time steps with total reward = 0.983000 (streak 25).
# Episode 44 finished after 24.000000 time steps with total reward = 0.976000 (streak 26).
# Episode 45 finished after 17.000000 time steps with total reward = 0.983000 (streak 27).
# Episode 46 finished after 25.000000 time steps with total reward = 0.975000 (streak 28).
# Episode 47 finished after 22.000000 time steps with total reward = 0.978000 (streak 29).
# Episode 48 finished after 21.000000 time steps with total reward = 0.979000 (streak 30).
# Episode 49 finished after 18.000000 time steps with total reward = 0.982000 (streak 31).
# Episode 50 finished after 20.000000 time steps with total reward = 0.980000 (streak 32).
# Episode 51 finished after 26.000000 time steps with total reward = 0.974000 (streak 33).
# Episode 52 finished after 23.000000 time steps with total reward = 0.977000 (streak 34).
# Episode 53 finished after 23.000000 time steps with total reward = 0.977000 (streak 35).
# Episode 54 finished after 20.000000 time steps with total reward = 0.980000 (streak 36).
# Episode 55 finished after 27.000000 time steps with total reward = 0.973000 (streak 37).
# Episode 56 finished after 23.000000 time steps with total reward = 0.977000 (streak 38).
# Episode 57 finished after 17.000000 time steps with total reward = 0.983000 (streak 39).
# Episode 58 finished after 23.000000 time steps with total reward = 0.977000 (streak 40).
# Episode 59 finished after 18.000000 time steps with total reward = 0.982000 (streak 41).
# Episode 60 finished after 21.000000 time steps with total reward = 0.979000 (streak 42).
# Episode 61 finished after 17.000000 time steps with total reward = 0.983000 (streak 43).
# Episode 62 finished after 18.000000 time steps with total reward = 0.982000 (streak 44).
# Episode 63 finished after 17.000000 time steps with total reward = 0.983000 (streak 45).
# Episode 64 finished after 25.000000 time steps with total reward = 0.975000 (streak 46).
# Episode 65 finished after 20.000000 time steps with total reward = 0.980000 (streak 47).
# Episode 66 finished after 20.000000 time steps with total reward = 0.980000 (streak 48).
# Episode 67 finished after 18.000000 time steps with total reward = 0.982000 (streak 49).
# Episode 68 finished after 17.000000 time steps with total reward = 0.983000 (streak 50).
# Episode 69 finished after 15.000000 time steps with total reward = 0.985000 (streak 51).
# Episode 70 finished after 17.000000 time steps with total reward = 0.983000 (streak 52).
# Episode 71 finished after 19.000000 time steps with total reward = 0.981000 (streak 53).
# Episode 72 finished after 18.000000 time steps with total reward = 0.982000 (streak 54).
# Episode 73 finished after 17.000000 time steps with total reward = 0.983000 (streak 55).
# Episode 74 finished after 17.000000 time steps with total reward = 0.983000 (streak 56).
# Episode 75 finished after 15.000000 time steps with total reward = 0.985000 (streak 57).
# Episode 76 finished after 15.000000 time steps with total reward = 0.985000 (streak 58).
# Episode 77 finished after 20.000000 time steps with total reward = 0.980000 (streak 59).
# Episode 78 finished after 17.000000 time steps with total reward = 0.983000 (streak 60).
# Episode 79 finished after 15.000000 time steps with total reward = 0.985000 (streak 61).
# Episode 80 finished after 24.000000 time steps with total reward = 0.976000 (streak 62).
# Episode 81 finished after 22.000000 time steps with total reward = 0.978000 (streak 63).
# Episode 82 finished after 15.000000 time steps with total reward = 0.985000 (streak 64).
# Episode 83 finished after 15.000000 time steps with total reward = 0.985000 (streak 65).
# Episode 84 finished after 18.000000 time steps with total reward = 0.982000 (streak 66).
# Episode 85 finished after 15.000000 time steps with total reward = 0.985000 (streak 67).
# Episode 86 finished after 15.000000 time steps with total reward = 0.985000 (streak 68).
# Episode 87 finished after 16.000000 time steps with total reward = 0.984000 (streak 69).
# Episode 88 finished after 16.000000 time steps with total reward = 0.984000 (streak 70).
# Episode 89 finished after 19.000000 time steps with total reward = 0.981000 (streak 71).
# Episode 90 finished after 17.000000 time steps with total reward = 0.983000 (streak 72).
# Episode 91 finished after 15.000000 time steps with total reward = 0.985000 (streak 73).
# Episode 92 finished after 15.000000 time steps with total reward = 0.985000 (streak 74).
# Episode 93 finished after 15.000000 time steps with total reward = 0.985000 (streak 75).
# Episode 94 finished after 15.000000 time steps with total reward = 0.985000 (streak 76).
# Episode 95 finished after 15.000000 time steps with total reward = 0.985000 (streak 77).
# Episode 96 finished after 15.000000 time steps with total reward = 0.985000 (streak 78).
# Episode 97 finished after 15.000000 time steps with total reward = 0.985000 (streak 79).
# Episode 98 finished after 15.000000 time steps with total reward = 0.985000 (streak 80).
# Episode 99 finished after 15.000000 time steps with total reward = 0.985000 (streak 81).
# Episode 100 finished after 15.000000 time steps with total reward = 0.985000 (streak 82).
# Episode 101 finished after 15.000000 time steps with total reward = 0.985000 (streak 83).
# Episode 102 finished after 15.000000 time steps with total reward = 0.985000 (streak 84).
# Episode 103 finished after 15.000000 time steps with total reward = 0.985000 (streak 85).
# Episode 104 finished after 15.000000 time steps with total reward = 0.985000 (streak 86).
# Episode 105 finished after 15.000000 time steps with total reward = 0.985000 (streak 87).
# Episode 106 finished after 15.000000 time steps with total reward = 0.985000 (streak 88).
# Episode 107 finished after 15.000000 time steps with total reward = 0.985000 (streak 89).
# Episode 108 finished after 15.000000 time steps with total reward = 0.985000 (streak 90).
# Episode 109 finished after 15.000000 time steps with total reward = 0.985000 (streak 91).
# Episode 110 finished after 15.000000 time steps with total reward = 0.985000 (streak 92).
# Episode 111 finished after 15.000000 time steps with total reward = 0.985000 (streak 93).
# Episode 112 finished after 15.000000 time steps with total reward = 0.985000 (streak 94).
# Episode 113 finished after 15.000000 time steps with total reward = 0.985000 (streak 95).
# Episode 114 finished after 15.000000 time steps with total reward = 0.985000 (streak 96).
# Episode 115 finished after 15.000000 time steps with total reward = 0.985000 (streak 97).
# Episode 116 finished after 15.000000 time steps with total reward = 0.985000 (streak 98).
# Episode 117 finished after 15.000000 time steps with total reward = 0.985000 (streak 99).
# Episode 118 finished after 15.000000 time steps with total reward = 0.985000 (streak 100).
# FINAL ACTION TABLE
#
# Action N table
#  [[ 8.36432356e-01  5.66937669e-01  1.69491395e-01  9.04860308e-01
#    9.04855882e-01  9.15018471e-01  8.92010032e-01  5.31183063e-01
#   -5.58968898e-03 -5.49826434e-03]
#  [ 8.27734974e-01  8.75003295e-01  8.75008513e-01  8.84861395e-01
#    9.25254486e-01  9.25068934e-01  9.13885960e-01  8.38888415e-01
#   -4.66261353e-03  6.01311240e-01]
#  [ 8.55597513e-01  8.00938399e-01 -2.54997504e-03 -5.66422623e-03
#    9.35627160e-01  9.35628163e-01  9.46089055e-01 -5.73300046e-03
#   -4.50272055e-03 -5.39831107e-03]
#  [-2.91747673e-03 -3.41938677e-03 -3.71865109e-03 -4.85650525e-03
#    8.71896923e-01  9.56655611e-01  9.56655611e-01  9.45979254e-01
#    9.13457874e-01 -3.85729151e-03]
#  [-1.98663938e-03 -2.60628685e-03 -3.27101235e-03 -1.98145843e-03
#    9.14777268e-01  9.56287396e-01  9.67328855e-01 -2.76439998e-03
#   -3.72899121e-03  1.17815521e-01]
#  [-2.80958362e-03 -3.19959245e-03 -3.27886389e-03  5.98644558e-01
#   -5.67432280e-03 -3.33505261e-03 -4.89731565e-03  8.59028085e-01
#   -3.97856006e-03 -3.31558638e-03]
#  [-3.89760898e-03 -3.84166445e-03 -4.12671715e-03 -4.17529930e-03
#   -3.81836133e-03  8.77742242e-01  8.99433244e-01  9.31289440e-01
#    9.46074304e-01  9.56655164e-01]
#  [-3.95958542e-03 -4.23899569e-03 -3.54562189e-03 -3.06277540e-03
#   -3.87917326e-03 -4.11365746e-03  6.41434620e-01  9.56636567e-01
#    9.56652297e-01  9.67328899e-01]
#  [-3.47079705e-03 -4.02123568e-03 -3.30669416e-03 -2.81628140e-03
#   -2.84208742e-03 -2.51295744e-03  4.40987330e-01  9.45830278e-01
#    9.56570601e-01  9.88764620e-01]
#  [-3.45025323e-03 -4.00460496e-03 -4.28515501e-03 -2.69549773e-03
#   -2.70305280e-03 -9.92000000e-04  4.08864627e-01  5.28328192e-01
#   -8.00000000e-04  0.00000000e+00]]
#
# Action S table
#  [[ 0.19964972  0.05446745  0.02566461  0.91501916  0.90485759  0.78304129
#   -0.00676425 -0.00615926 -0.00542488 -0.00543206]
#  [ 0.83693591  0.88487208  0.89482028  0.89477742  0.93562784  0.93475076
#    0.43117931 -0.00594701 -0.00447854 -0.00433663]
#  [ 0.86527313  0.86079703 -0.0046458   0.06209512  0.94608905  0.93562816
#    0.93561961 -0.00555211  0.56909256 -0.00448474]
#  [-0.00380396 -0.00381469 -0.00381374  0.92104234  0.88109546  0.94608905
#    0.93080563  0.77443322 -0.00479554 -0.00477855]
#  [-0.00198557 -0.0025885  -0.00344899  0.95195532  0.96730503  0.95659855
#    0.8268959   0.11776976 -0.00365117 -0.00455848]
#  [-0.00284741 -0.00333787  0.64916336 -0.00191078 -0.00489779 -0.00581676
#   -0.0057601   0.91887914  0.80094545  0.93370589]
#  [-0.0036086  -0.00400792 -0.00409912 -0.00346864 -0.00332555  0.92949685
#    0.94596503  0.95393667  0.94506644  0.96732682]
#  [-0.0036239  -0.00334061 -0.00272318 -0.00415664  0.23510451  0.74073267
#    0.69352912  0.96732888  0.97811     0.97811   ]
#  [-0.0034771  -0.00358754 -0.00281086 -0.00238085 -0.0019478  -0.00259406
#    0.45550808  0.94466645  0.95645822  0.98899998]
#  [-0.00424868 -0.00412791 -0.00412293 -0.00333897 -0.00238085  0.48535067
#    0.56076742  0.92560459  0.8         0.        ]]
#
# Action E table
#  [[ 0.84606419  0.06671398  0.04035814  0.89470334  0.92527188  0.89828821
#    0.7357867  -0.00597628 -0.00606205 -0.00451426]
#  [ 0.85562039  0.86526764  0.88434668  0.89476487  0.93562816  0.94608905
#    0.93552952 -0.00569912  0.58654002 -0.00433661]
#  [ 0.85066221  0.86502459 -0.00380763  0.74800623  0.92518973  0.95665561
#    0.94608672 -0.00572629  0.50263859 -0.00479764]
#  [-0.00289453 -0.00294426 -0.00343148  0.5749928   0.89963291  0.9673289
#    0.95322514  0.69490058 -0.00288759 -0.00459047]
#  [-0.00288523 -0.00323183  0.42655303  0.7098675   0.91180888  0.94476567
#    0.90010988  0.74212084  0.47151703 -0.00439963]
#  [-0.00386467 -0.00341793 -0.00424385 -0.002821   -0.00568627  0.87445365
#   -0.00561155  0.94604221 -0.00393651  0.9460877 ]
#  [-0.00391447 -0.00366727 -0.00348347 -0.00403005 -0.00367873  0.77623826
#    0.68819467  0.95665371  0.9673289   0.97811   ]
#  [-0.00345631 -0.00347591 -0.00319938 -0.00402603 -0.00332429  0.45080284
#    0.64091003  0.9460772   0.95665554  0.989     ]
#  [-0.00272875 -0.00439457 -0.00339393 -0.0027031  -0.00268388 -0.00179195
#    0.26117882  0.92592543  0.93386793  1.        ]
#  [-0.00396075 -0.0034427  -0.0042474  -0.00175232 -0.00263866  0.230167
#    0.44696771  0.90497157  0.67400171  0.        ]]
#
# Action W table
#  [[ 0.80763156  0.06784478  0.0312351   0.90360123  0.91478819  0.90292946
#    0.73584839 -0.00632668 -0.00591174 -0.00539044]
#  [ 0.80085355  0.87500901  0.88487199  0.90486897  0.91483726  0.9355261
#    0.63719063 -0.00613737  0.1964841  -0.00524206]
#  [ 0.8366166   0.87502336 -0.0031618  -0.00545771  0.92524111  0.93562816
#    0.92315455 -0.00593313  0.6921343  -0.00519368]
#  [-0.00290507 -0.00365124 -0.00575266  0.3271294   0.93562486  0.94608905
#    0.93558595  0.87951371  0.29818794 -0.00446374]
#  [-0.00373727 -0.00256979 -0.00427749 -0.00193613  0.95308392  0.95665556
#    0.89448739 -0.00369793 -0.00458254 -0.00480494]
#  [-0.00197796 -0.0032298  -0.00411163  0.7456764  -0.00582216  0.6014945
#   -0.00567468  0.09128106 -0.00362824  0.93449563]
#  [-0.00294565 -0.00331191 -0.00359311 -0.0031618  -0.00346864  0.19635753
#    0.91478508  0.93512695  0.94867437  0.9356149 ]
#  [-0.00368561 -0.00340359 -0.00400361 -0.00373823 -0.00409775  0.36696693
#    0.89673443  0.94580592  0.95665517  0.94604358]
#  [-0.00285538 -0.00365138 -0.00340943 -0.00187904 -0.0024126  -0.00272591
#    0.74072025  0.95665193  0.9673289   0.97810986]
#  [-0.00316687 -0.00411275 -0.00462211 -0.00284107 -0.00270808 -0.00277138
#    0.43269208  0.94488925  0.95562806  0.        ]]

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"learning_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [learning_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Learning Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Learning Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(learning_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"learning_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (119,)
# explore_rate Shape:  (119,)
# learning_rate Shape:  (119,)
# num_streaks Shape:  (119,)
# length_episode Shape:  (119,)
