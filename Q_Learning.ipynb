# %% [markdown]
# # $$ Q - Learning $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os

# imports from project
from utils.plotting import plot_line_graphs_overlayed
from utils.file_management import create_folder_structure
from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","Q_LEANING")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\results\\Q_LEANING'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 1000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99
LEARNING_RATE = 0.01

'''
CREATING RESULTS SAVING FOLDERS
'''
SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99,
             learning_rate:float= 0.01):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the learning related parameters
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    # Initialize q_table
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)
    
    #Initializain num streaks
    num_streaks= 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state = state_to_bucket(obv)
        total_reward = 0


        for t in range(MAX_T):

            # Select an action
            action = epsilon_greedy_police(state, explore_rate,q_table)

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            next_state = state_to_bucket(obv)
            total_reward += reward

            # Update the Q based on the result
            best_q = np.amax(q_table[next_state])
            q_table[state + (action,)] += learning_rate * (reward + discount_factor * (best_q) - q_table[state + (action,)])

            # Setting up for the next iteration
            state = next_state


            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print(f"Episode {episode} finished after {t} time steps with total reward = {total_reward} (streak {num_streaks}).")

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print(f"Episode {episode} timed out at {t} with total reward = {total_reward}.")

        # Appending Episode values to the list
        reward_episode_list.append(total_reward)
        explore_rate_episode_list.append(explore_rate)
        num_streaks_episode_list.append(num_streaks)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)


    print("FINAL ACTION TABLE \n")
    acts = ["N", "S", "E", "W"]
    for i in range(q_table.shape[2]):
        print(f"Action {acts[i]} table \n {q_table[:,:,i]}\n")

    return (np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def epsilon_greedy_police(state, explore_rate,q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE and LEARNING_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
reward_episode_array,explore_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR,
                learning_rate = LEARNING_RATE)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# eak 2).
# Episode 313 finished after 126 time steps with total reward = 0.8739999999999999 (streak 3).
# Episode 314 finished after 68 time steps with total reward = 0.9319999999999999 (streak 0).
# Episode 315 finished after 47 time steps with total reward = 0.953 (streak 1).
# Episode 316 finished after 69 time steps with total reward = 0.9309999999999999 (streak 2).
# Episode 317 finished after 28 time steps with total reward = 0.972 (streak 3).
# Episode 318 finished after 25 time steps with total reward = 0.975 (streak 4).
# Episode 319 finished after 64 time steps with total reward = 0.9359999999999999 (streak 5).
# Episode 320 finished after 30 time steps with total reward = 0.97 (streak 6).
# Episode 321 finished after 109 time steps with total reward = 0.8909999999999999 (streak 7).
# Episode 322 finished after 89 time steps with total reward = 0.9109999999999999 (streak 0).
# Episode 323 finished after 54 time steps with total reward = 0.946 (streak 1).
# Episode 324 finished after 60 time steps with total reward = 0.94 (streak 2).
# Episode 325 finished after 52 time steps with total reward = 0.948 (streak 3).
# Episode 326 finished after 61 time steps with total reward = 0.939 (streak 4).
# Episode 327 finished after 38 time steps with total reward = 0.962 (streak 5).
# Episode 328 finished after 56 time steps with total reward = 0.944 (streak 6).
# Episode 329 finished after 39 time steps with total reward = 0.961 (streak 7).
# Episode 330 finished after 321 time steps with total reward = 0.6789999999999998 (streak 8).
# Episode 331 finished after 33 time steps with total reward = 0.967 (streak 0).
# Episode 332 finished after 47 time steps with total reward = 0.953 (streak 1).
# Episode 333 finished after 31 time steps with total reward = 0.969 (streak 2).
# Episode 334 finished after 63 time steps with total reward = 0.9369999999999999 (streak 3).
# Episode 335 finished after 22 time steps with total reward = 0.978 (streak 4).
# Episode 336 finished after 50 time steps with total reward = 0.95 (streak 5).
# Episode 337 finished after 75 time steps with total reward = 0.9249999999999999 (streak 6).
# Episode 338 finished after 33 time steps with total reward = 0.967 (streak 7).
# Episode 339 finished after 57 time steps with total reward = 0.943 (streak 8).
# Episode 340 finished after 70 time steps with total reward = 0.9299999999999999 (streak 9).
# Episode 341 finished after 93 time steps with total reward = 0.9069999999999999 (streak 10).
# Episode 342 finished after 29 time steps with total reward = 0.971 (streak 11).
# Episode 343 finished after 48 time steps with total reward = 0.952 (streak 12).
# Episode 344 finished after 34 time steps with total reward = 0.966 (streak 13).
# Episode 345 finished after 48 time steps with total reward = 0.952 (streak 14).
# Episode 346 finished after 37 time steps with total reward = 0.963 (streak 15).
# Episode 347 finished after 86 time steps with total reward = 0.9139999999999999 (streak 16).
# Episode 348 finished after 38 time steps with total reward = 0.962 (streak 17).
# Episode 349 finished after 26 time steps with total reward = 0.974 (streak 18).
# Episode 350 finished after 57 time steps with total reward = 0.943 (streak 19).
# Episode 351 finished after 171 time steps with total reward = 0.8289999999999998 (streak 20).
# Episode 352 finished after 57 time steps with total reward = 0.943 (streak 0).
# Episode 353 finished after 21 time steps with total reward = 0.979 (streak 1).
# Episode 354 finished after 81 time steps with total reward = 0.9189999999999999 (streak 2).
# Episode 355 finished after 39 time steps with total reward = 0.961 (streak 3).
# Episode 356 finished after 24 time steps with total reward = 0.976 (streak 4).
# Episode 357 finished after 52 time steps with total reward = 0.948 (streak 5).
# Episode 358 finished after 68 time steps with total reward = 0.9319999999999999 (streak 6).
# Episode 359 finished after 37 time steps with total reward = 0.963 (streak 7).
# Episode 360 finished after 87 time steps with total reward = 0.9129999999999999 (streak 8).
# Episode 361 finished after 83 time steps with total reward = 0.9169999999999999 (streak 9).
# Episode 362 finished after 43 time steps with total reward = 0.957 (streak 10).
# Episode 363 finished after 40 time steps with total reward = 0.96 (streak 11).
# Episode 364 finished after 28 time steps with total reward = 0.972 (streak 12).
# Episode 365 finished after 67 time steps with total reward = 0.9329999999999999 (streak 13).
# Episode 366 finished after 42 time steps with total reward = 0.958 (streak 14).
# Episode 367 finished after 56 time steps with total reward = 0.944 (streak 15).
# Episode 368 finished after 62 time steps with total reward = 0.938 (streak 16).
# Episode 369 finished after 32 time steps with total reward = 0.968 (streak 17).
# Episode 370 finished after 28 time steps with total reward = 0.972 (streak 18).
# Episode 371 finished after 29 time steps with total reward = 0.971 (streak 19).
# Episode 372 finished after 244 time steps with total reward = 0.7559999999999998 (streak 20).
# Episode 373 finished after 66 time steps with total reward = 0.9339999999999999 (streak 0).
# Episode 374 finished after 52 time steps with total reward = 0.948 (streak 1).
# Episode 375 finished after 72 time steps with total reward = 0.9279999999999999 (streak 2).
# Episode 376 finished after 28 time steps with total reward = 0.972 (streak 3).
# Episode 377 finished after 36 time steps with total reward = 0.964 (streak 4).
# Episode 378 finished after 33 time steps with total reward = 0.967 (streak 5).
# Episode 379 finished after 40 time steps with total reward = 0.96 (streak 6).
# Episode 380 finished after 34 time steps with total reward = 0.966 (streak 7).
# Episode 381 finished after 82 time steps with total reward = 0.9179999999999999 (streak 8).
# Episode 382 finished after 31 time steps with total reward = 0.969 (streak 9).
# Episode 383 finished after 26 time steps with total reward = 0.974 (streak 10).
# Episode 384 finished after 43 time steps with total reward = 0.957 (streak 11).
# Episode 385 finished after 65 time steps with total reward = 0.9349999999999999 (streak 12).
# Episode 386 finished after 63 time steps with total reward = 0.9369999999999999 (streak 13).
# Episode 387 finished after 30 time steps with total reward = 0.97 (streak 14).
# Episode 388 finished after 40 time steps with total reward = 0.96 (streak 15).
# Episode 389 finished after 77 time steps with total reward = 0.9229999999999999 (streak 16).
# Episode 390 finished after 37 time steps with total reward = 0.963 (streak 17).
# Episode 391 finished after 22 time steps with total reward = 0.978 (streak 18).
# Episode 392 finished after 56 time steps with total reward = 0.944 (streak 19).
# Episode 393 finished after 48 time steps with total reward = 0.952 (streak 20).
# Episode 394 finished after 36 time steps with total reward = 0.964 (streak 21).
# Episode 395 finished after 52 time steps with total reward = 0.948 (streak 22).
# Episode 396 finished after 64 time steps with total reward = 0.9359999999999999 (streak 23).
# Episode 397 finished after 47 time steps with total reward = 0.953 (streak 24).
# Episode 398 finished after 35 time steps with total reward = 0.965 (streak 25).
# Episode 399 finished after 44 time steps with total reward = 0.956 (streak 26).
# Episode 400 finished after 25 time steps with total reward = 0.975 (streak 27).
# Episode 401 finished after 56 time steps with total reward = 0.944 (streak 28).
# Episode 402 finished after 56 time steps with total reward = 0.944 (streak 29).
# Episode 403 finished after 33 time steps with total reward = 0.967 (streak 30).
# Episode 404 finished after 20 time steps with total reward = 0.98 (streak 31).
# Episode 405 finished after 78 time steps with total reward = 0.9219999999999999 (streak 32).
# Episode 406 finished after 26 time steps with total reward = 0.974 (streak 33).
# Episode 407 finished after 31 time steps with total reward = 0.969 (streak 34).
# Episode 408 finished after 25 time steps with total reward = 0.975 (streak 35).
# Episode 409 finished after 43 time steps with total reward = 0.957 (streak 36).
# Episode 410 finished after 31 time steps with total reward = 0.969 (streak 37).
# Episode 411 finished after 44 time steps with total reward = 0.956 (streak 38).
# Episode 412 finished after 65 time steps with total reward = 0.9349999999999999 (streak 39).
# Episode 413 finished after 34 time steps with total reward = 0.966 (streak 40).
# Episode 414 finished after 34 time steps with total reward = 0.966 (streak 41).
# Episode 415 finished after 42 time steps with total reward = 0.958 (streak 42).
# Episode 416 finished after 29 time steps with total reward = 0.971 (streak 43).
# Episode 417 finished after 37 time steps with total reward = 0.963 (streak 44).
# Episode 418 finished after 48 time steps with total reward = 0.952 (streak 45).
# Episode 419 finished after 23 time steps with total reward = 0.977 (streak 46).
# Episode 420 finished after 33 time steps with total reward = 0.967 (streak 47).
# Episode 421 finished after 64 time steps with total reward = 0.9359999999999999 (streak 48).
# Episode 422 finished after 39 time steps with total reward = 0.961 (streak 49).
# Episode 423 finished after 23 time steps with total reward = 0.977 (streak 50).
# Episode 424 finished after 24 time steps with total reward = 0.976 (streak 51).
# Episode 425 finished after 23 time steps with total reward = 0.977 (streak 52).
# Episode 426 finished after 57 time steps with total reward = 0.943 (streak 53).
# Episode 427 finished after 37 time steps with total reward = 0.963 (streak 54).
# Episode 428 finished after 24 time steps with total reward = 0.976 (streak 55).
# Episode 429 finished after 81 time steps with total reward = 0.9189999999999999 (streak 56).
# Episode 430 finished after 35 time steps with total reward = 0.965 (streak 57).
# Episode 431 finished after 21 time steps with total reward = 0.979 (streak 58).
# Episode 432 finished after 50 time steps with total reward = 0.95 (streak 59).
# Episode 433 finished after 47 time steps with total reward = 0.953 (streak 60).
# Episode 434 finished after 31 time steps with total reward = 0.969 (streak 61).
# Episode 435 finished after 51 time steps with total reward = 0.949 (streak 62).
# Episode 436 finished after 39 time steps with total reward = 0.961 (streak 63).
# Episode 437 finished after 26 time steps with total reward = 0.974 (streak 64).
# Episode 438 finished after 29 time steps with total reward = 0.971 (streak 65).
# Episode 439 finished after 19 time steps with total reward = 0.981 (streak 66).
# Episode 440 finished after 51 time steps with total reward = 0.949 (streak 67).
# Episode 441 finished after 26 time steps with total reward = 0.974 (streak 68).
# Episode 442 finished after 37 time steps with total reward = 0.963 (streak 69).
# Episode 443 finished after 36 time steps with total reward = 0.964 (streak 70).
# Episode 444 finished after 57 time steps with total reward = 0.943 (streak 71).
# Episode 445 finished after 24 time steps with total reward = 0.976 (streak 72).
# Episode 446 finished after 24 time steps with total reward = 0.976 (streak 73).
# Episode 447 finished after 59 time steps with total reward = 0.941 (streak 74).
# Episode 448 finished after 28 time steps with total reward = 0.972 (streak 75).
# Episode 449 finished after 39 time steps with total reward = 0.961 (streak 76).
# Episode 450 finished after 40 time steps with total reward = 0.96 (streak 77).
# Episode 451 finished after 31 time steps with total reward = 0.969 (streak 78).
# Episode 452 finished after 43 time steps with total reward = 0.957 (streak 79).
# Episode 453 finished after 41 time steps with total reward = 0.959 (streak 80).
# Episode 454 finished after 31 time steps with total reward = 0.969 (streak 81).
# Episode 455 finished after 27 time steps with total reward = 0.973 (streak 82).
# Episode 456 finished after 34 time steps with total reward = 0.966 (streak 83).
# Episode 457 finished after 53 time steps with total reward = 0.947 (streak 84).
# Episode 458 finished after 41 time steps with total reward = 0.959 (streak 85).
# Episode 459 finished after 30 time steps with total reward = 0.97 (streak 86).
# Episode 460 finished after 29 time steps with total reward = 0.971 (streak 87).
# Episode 461 finished after 41 time steps with total reward = 0.959 (streak 88).
# Episode 462 finished after 45 time steps with total reward = 0.955 (streak 89).
# Episode 463 finished after 33 time steps with total reward = 0.967 (streak 90).
# Episode 464 finished after 22 time steps with total reward = 0.978 (streak 91).
# Episode 465 finished after 23 time steps with total reward = 0.977 (streak 92).
# Episode 466 finished after 30 time steps with total reward = 0.97 (streak 93).
# Episode 467 finished after 35 time steps with total reward = 0.965 (streak 94).
# Episode 468 finished after 43 time steps with total reward = 0.957 (streak 95).
# Episode 469 finished after 39 time steps with total reward = 0.961 (streak 96).
# Episode 470 finished after 60 time steps with total reward = 0.94 (streak 97).
# Episode 471 finished after 33 time steps with total reward = 0.967 (streak 98).
# Episode 472 finished after 25 time steps with total reward = 0.975 (streak 99).
# Episode 473 finished after 27 time steps with total reward = 0.973 (streak 100).
# FINAL ACTION TABLE
#
# Action N table
#  [[-5.22852578e-03 -4.07544779e-03 -3.87501128e-03 -3.52661106e-03
#   -2.39961140e-03 -2.37981291e-03 -1.68287033e-03 -1.50716616e-03
#   -1.30176718e-03 -1.31083026e-03]
#    3.83112897e-02  0.00000000e+00]]
#
# Action W table
#  [[-5.23167425e-03 -4.06998949e-03 -3.86724066e-03 -3.53381578e-03
#   -2.38543233e-03 -2.36708988e-03 -1.68669587e-03 -1.50928511e-03
#   -1.30385604e-03 -1.31026577e-03]
#  [-4.64513810e-03 -4.25615935e-03 -3.99719999e-03 -3.52783604e-03
#   -3.52294023e-03 -2.12307321e-03 -1.84894301e-03 -1.69428157e-03
#   -1.05828134e-03 -1.30693538e-03]
#  [-4.18874870e-03 -3.92361959e-03 -3.82700470e-03 -3.53418545e-03
#   -1.46323195e-03 -1.39567321e-03 -1.57307857e-03 -1.74410768e-03
#   -7.96099811e-04 -1.30551847e-03]
#  [-3.86252078e-03 -3.74544428e-03 -3.13284393e-03 -3.20841618e-03
#   -1.40645365e-03 -1.40272507e-03 -1.58321716e-03 -1.00322835e-03
#   -8.91050521e-04 -1.30652439e-03]
#  [-3.60281061e-03 -3.42811174e-03 -3.05946674e-03 -2.86566668e-03
#   -1.34636744e-03 -1.29629243e-03 -1.18196466e-03 -1.10103173e-03
#   -8.04146748e-04 -6.63783495e-04]
#  [-3.30541114e-03 -2.94121535e-03 -2.68832773e-03 -2.44454746e-03
#   -1.28164331e-03 -1.21221422e-03 -1.14854032e-03 -1.03195353e-03
#   -9.37353098e-04 -5.18483534e-04]
#  [-3.30912268e-03 -2.73960125e-03 -2.35027240e-03 -1.95111694e-03
#   -9.49226415e-04 -8.72059260e-04 -6.12627014e-04 -1.00895009e-03
#   -9.67477896e-04 -3.38388583e-04]
#  [-1.44656124e-03 -1.44636168e-03 -1.83127978e-03 -1.53339394e-03
#   -1.03618681e-03 -6.92456431e-04 -4.74820270e-04 -4.67496760e-04
#   -8.86574809e-05 -1.43067827e-04]
#  [-1.44788784e-03 -1.45116629e-03 -1.59382824e-03 -1.45174575e-03
#   -6.46183907e-04 -4.38945120e-04 -3.13952176e-04 -4.74956199e-04
#   -5.23581832e-05  4.36188556e-04]
#  [-1.44909896e-03 -1.44986613e-03 -1.45854801e-03 -1.30000981e-03
#   -9.41574205e-04 -1.78603465e-04 -1.69459888e-04  3.86408677e-03
#    3.52902772e-04  0.00000000e+00]]

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (474,)
# explore_rate Shape:  (474,)
# num_streaks Shape:  (474,)
# length_episode Shape:  (474,)
