# %% [markdown]
# # $$ Q - Learning $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os
from collections import defaultdict


# imports from project
from utils.plotting import plot_line_graphs_overlayed
from utils.file_management import create_folder_structure
from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","Q_LEANING")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\results\\Q_LEANING'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 1000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99
LEARNING_RATE = 0.3

'''
CREATING RESULTS SAVING FOLDERS
'''
SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99,
             learning_rate:float= 0.01):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the learning related parameters
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    # Initialize q_table
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    
    #Initializain num streaks
    num_streaks= 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state = state_to_bucket(obv)
        total_reward = 0


        for t in range(MAX_T):

            # Select an action
            action = epsilon_greedy_police(state, explore_rate,Q)

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            next_state = state_to_bucket(obv)
            total_reward += reward

            # Update the Q based on the result
            best_q = np.amax(Q[next_state])
            Q[state][action] += learning_rate * (reward + discount_factor * (best_q) - Q[state][action])

            # Setting up for the next iteration
            state = next_state


            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print(f"Episode {episode} finished after {t} time steps with total reward = {total_reward} (streak {num_streaks}).")

                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print(f"Episode {episode} timed out at {t} with total reward = {total_reward}.")

        # Appending Episode values to the list
        reward_episode_list.append(total_reward)
        explore_rate_episode_list.append(explore_rate)
        num_streaks_episode_list.append(num_streaks)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)


    return (Q,np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def epsilon_greedy_police(state, explore_rate,q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE and LEARNING_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
Q,reward_episode_array,explore_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR,
                learning_rate = LEARNING_RATE)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# eward = 0.9319999999999999 (streak 0).
# Episode 327 finished after 44 time steps with total reward = 0.8239999999999998 (streak 1).
# Episode 328 finished after 33 time steps with total reward = 0.8679999999999999 (streak 0).
# Episode 329 finished after 18 time steps with total reward = 0.9279999999999999 (streak 0).
# Episode 330 finished after 36 time steps with total reward = 0.8559999999999999 (streak 1).
# Episode 331 finished after 20 time steps with total reward = 0.9199999999999999 (streak 0).
# Episode 332 finished after 33 time steps with total reward = 0.8679999999999999 (streak 1).
# Episode 333 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 334 finished after 39 time steps with total reward = 0.8439999999999999 (streak 1).
# Episode 335 finished after 33 time steps with total reward = 0.8679999999999999 (streak 0).
# Episode 336 finished after 18 time steps with total reward = 0.9279999999999999 (streak 0).
# Episode 337 finished after 40 time steps with total reward = 0.8399999999999999 (streak 1).
# Episode 338 finished after 35 time steps with total reward = 0.8599999999999999 (streak 0).
# Episode 339 finished after 18 time steps with total reward = 0.9279999999999999 (streak 0).
# Episode 340 finished after 15 time steps with total reward = 0.94 (streak 1).
# Episode 341 finished after 34 time steps with total reward = 0.8639999999999999 (streak 2).
# Episode 342 finished after 38 time steps with total reward = 0.8479999999999999 (streak 0).
# Episode 343 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 344 finished after 34 time steps with total reward = 0.8639999999999999 (streak 1).
# Episode 345 finished after 19 time steps with total reward = 0.9239999999999999 (streak 0).
# Episode 346 finished after 36 time steps with total reward = 0.8559999999999999 (streak 1).
# Episode 347 finished after 19 time steps with total reward = 0.9239999999999999 (streak 0).
# Episode 348 finished after 34 time steps with total reward = 0.8639999999999999 (streak 1).
# Episode 349 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 350 finished after 32 time steps with total reward = 0.8719999999999999 (streak 1).
# Episode 351 finished after 39 time steps with total reward = 0.8439999999999999 (streak 0).
# Episode 352 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 353 finished after 18 time steps with total reward = 0.9279999999999999 (streak 1).
# Episode 354 finished after 32 time steps with total reward = 0.8719999999999999 (streak 2).
# Episode 355 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 356 finished after 39 time steps with total reward = 0.8439999999999999 (streak 1).
# Episode 357 finished after 32 time steps with total reward = 0.8719999999999999 (streak 0).
# Episode 358 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 359 finished after 15 time steps with total reward = 0.94 (streak 1).
# Episode 360 finished after 36 time steps with total reward = 0.8559999999999999 (streak 2).
# Episode 361 finished after 36 time steps with total reward = 0.8559999999999999 (streak 0).
# Episode 362 finished after 19 time steps with total reward = 0.9239999999999999 (streak 0).
# Episode 363 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 364 finished after 34 time steps with total reward = 0.8639999999999999 (streak 2).
# Episode 365 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 366 finished after 40 time steps with total reward = 0.8399999999999999 (streak 1).
# Episode 367 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 368 finished after 34 time steps with total reward = 0.8639999999999999 (streak 1).
# Episode 369 finished after 19 time steps with total reward = 0.9239999999999999 (streak 0).
# Episode 370 finished after 32 time steps with total reward = 0.8719999999999999 (streak 1).
# Episode 371 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 372 finished after 39 time steps with total reward = 0.8439999999999999 (streak 1).
# Episode 373 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 374 finished after 32 time steps with total reward = 0.8719999999999999 (streak 1).
# Episode 375 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 376 finished after 19 time steps with total reward = 0.9239999999999999 (streak 1).
# Episode 377 finished after 33 time steps with total reward = 0.8679999999999999 (streak 2).
# Episode 378 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 379 finished after 37 time steps with total reward = 0.8519999999999999 (streak 1).
# Episode 380 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 381 finished after 33 time steps with total reward = 0.8679999999999999 (streak 1).
# Episode 382 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 383 finished after 18 time steps with total reward = 0.9279999999999999 (streak 1).
# Episode 384 finished after 32 time steps with total reward = 0.8719999999999999 (streak 2).
# Episode 385 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 386 finished after 13 time steps with total reward = 0.948 (streak 1).
# Episode 387 finished after 39 time steps with total reward = 0.8439999999999999 (streak 2).
# Episode 388 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 389 finished after 32 time steps with total reward = 0.8719999999999999 (streak 1).
# Episode 390 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 391 finished after 36 time steps with total reward = 0.8559999999999999 (streak 1).
# Episode 392 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 393 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 394 finished after 36 time steps with total reward = 0.8559999999999999 (streak 2).
# Episode 395 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 396 finished after 15 time steps with total reward = 0.94 (streak 1).
# Episode 397 finished after 31 time steps with total reward = 0.8759999999999999 (streak 2).
# Episode 398 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 399 finished after 38 time steps with total reward = 0.8479999999999999 (streak 1).
# Episode 400 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 401 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 402 finished after 31 time steps with total reward = 0.8759999999999999 (streak 2).
# Episode 403 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 404 finished after 18 time steps with total reward = 0.9279999999999999 (streak 1).
# Episode 405 finished after 31 time steps with total reward = 0.8759999999999999 (streak 2).
# Episode 406 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 407 finished after 13 time steps with total reward = 0.948 (streak 1).
# Episode 408 finished after 15 time steps with total reward = 0.94 (streak 2).
# Episode 409 finished after 35 time steps with total reward = 0.8599999999999999 (streak 3).
# Episode 410 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 411 finished after 13 time steps with total reward = 0.948 (streak 1).
# Episode 412 finished after 32 time steps with total reward = 0.8719999999999999 (streak 2).
# Episode 413 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 414 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 415 finished after 34 time steps with total reward = 0.8639999999999999 (streak 2).
# Episode 416 finished after 16 time steps with total reward = 0.9359999999999999 (streak 0).
# Episode 417 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 418 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 419 finished after 32 time steps with total reward = 0.8719999999999999 (streak 3).
# Episode 420 finished after 18 time steps with total reward = 0.9279999999999999 (streak 0).
# Episode 421 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 422 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 423 finished after 32 time steps with total reward = 0.8719999999999999 (streak 3).
# Episode 424 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 425 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 426 finished after 15 time steps with total reward = 0.94 (streak 2).
# Episode 427 finished after 35 time steps with total reward = 0.8599999999999999 (streak 3).
# Episode 428 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 429 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 430 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 431 finished after 32 time steps with total reward = 0.8719999999999999 (streak 3).
# Episode 432 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 433 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 434 finished after 17 time steps with total reward = 0.9319999999999999 (streak 2).
# Episode 435 finished after 32 time steps with total reward = 0.8719999999999999 (streak 3).
# Episode 436 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 437 finished after 15 time steps with total reward = 0.94 (streak 1).
# Episode 438 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 439 finished after 13 time steps with total reward = 0.948 (streak 3).
# Episode 440 finished after 32 time steps with total reward = 0.8719999999999999 (streak 4).
# Episode 441 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 442 finished after 17 time steps with total reward = 0.9319999999999999 (streak 1).
# Episode 443 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 444 finished after 13 time steps with total reward = 0.948 (streak 3).
# Episode 445 finished after 15 time steps with total reward = 0.94 (streak 4).
# Episode 446 finished after 31 time steps with total reward = 0.8759999999999999 (streak 5).
# Episode 447 finished after 14 time steps with total reward = 0.944 (streak 0).
# Episode 448 finished after 15 time steps with total reward = 0.94 (streak 1).
# Episode 449 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 450 finished after 13 time steps with total reward = 0.948 (streak 3).
# Episode 451 finished after 15 time steps with total reward = 0.94 (streak 4).
# Episode 452 finished after 14 time steps with total reward = 0.944 (streak 5).
# Episode 453 finished after 34 time steps with total reward = 0.8639999999999999 (streak 6).
# Episode 454 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 455 finished after 13 time steps with total reward = 0.948 (streak 1).
# Episode 456 finished after 15 time steps with total reward = 0.94 (streak 2).
# Episode 457 finished after 14 time steps with total reward = 0.944 (streak 3).
# Episode 458 finished after 13 time steps with total reward = 0.948 (streak 4).
# Episode 459 finished after 14 time steps with total reward = 0.944 (streak 5).
# Episode 460 finished after 14 time steps with total reward = 0.944 (streak 6).
# Episode 461 finished after 14 time steps with total reward = 0.944 (streak 7).
# Episode 462 finished after 14 time steps with total reward = 0.944 (streak 8).
# Episode 463 finished after 14 time steps with total reward = 0.944 (streak 9).
# Episode 464 finished after 14 time steps with total reward = 0.944 (streak 10).
# Episode 465 finished after 30 time steps with total reward = 0.8799999999999999 (streak 11).
# Episode 466 finished after 15 time steps with total reward = 0.94 (streak 0).
# Episode 467 finished after 14 time steps with total reward = 0.944 (streak 1).
# Episode 468 finished after 14 time steps with total reward = 0.944 (streak 2).
# Episode 469 finished after 14 time steps with total reward = 0.944 (streak 3).
# Episode 470 finished after 14 time steps with total reward = 0.944 (streak 4).
# Episode 471 finished after 14 time steps with total reward = 0.944 (streak 5).
# Episode 472 finished after 13 time steps with total reward = 0.948 (streak 6).
# Episode 473 finished after 14 time steps with total reward = 0.944 (streak 7).
# Episode 474 finished after 14 time steps with total reward = 0.944 (streak 8).
# Episode 475 finished after 14 time steps with total reward = 0.944 (streak 9).
# Episode 476 finished after 13 time steps with total reward = 0.948 (streak 10).
# Episode 477 finished after 15 time steps with total reward = 0.94 (streak 11).
# Episode 478 finished after 13 time steps with total reward = 0.948 (streak 12).
# Episode 479 finished after 14 time steps with total reward = 0.944 (streak 13).
# Episode 480 finished after 14 time steps with total reward = 0.944 (streak 14).
# Episode 481 finished after 14 time steps with total reward = 0.944 (streak 15).
# Episode 482 finished after 13 time steps with total reward = 0.948 (streak 16).
# Episode 483 finished after 14 time steps with total reward = 0.944 (streak 17).
# Episode 484 finished after 13 time steps with total reward = 0.948 (streak 18).
# Episode 485 finished after 15 time steps with total reward = 0.94 (streak 19).
# Episode 486 finished after 13 time steps with total reward = 0.948 (streak 20).
# Episode 487 finished after 14 time steps with total reward = 0.944 (streak 21).
# Episode 488 finished after 13 time steps with total reward = 0.948 (streak 22).
# Episode 489 finished after 14 time steps with total reward = 0.944 (streak 23).
# Episode 490 finished after 14 time steps with total reward = 0.944 (streak 24).
# Episode 491 finished after 14 time steps with total reward = 0.944 (streak 25).
# Episode 492 finished after 13 time steps with total reward = 0.948 (streak 26).
# Episode 493 finished after 13 time steps with total reward = 0.948 (streak 27).
# Episode 494 finished after 14 time steps with total reward = 0.944 (streak 28).
# Episode 495 finished after 14 time steps with total reward = 0.944 (streak 29).
# Episode 496 finished after 14 time steps with total reward = 0.944 (streak 30).
# Episode 497 finished after 13 time steps with total reward = 0.948 (streak 31).
# Episode 498 finished after 13 time steps with total reward = 0.948 (streak 32).
# Episode 499 finished after 14 time steps with total reward = 0.944 (streak 33).
# Episode 500 finished after 14 time steps with total reward = 0.944 (streak 34).
# Episode 501 finished after 13 time steps with total reward = 0.948 (streak 35).
# Episode 502 finished after 14 time steps with total reward = 0.944 (streak 36).
# Episode 503 finished after 13 time steps with total reward = 0.948 (streak 37).
# Episode 504 finished after 13 time steps with total reward = 0.948 (streak 38).
# Episode 505 finished after 14 time steps with total reward = 0.944 (streak 39).
# Episode 506 finished after 14 time steps with total reward = 0.944 (streak 40).
# Episode 507 finished after 13 time steps with total reward = 0.948 (streak 41).
# Episode 508 finished after 14 time steps with total reward = 0.944 (streak 42).
# Episode 509 finished after 13 time steps with total reward = 0.948 (streak 43).
# Episode 510 finished after 13 time steps with total reward = 0.948 (streak 44).
# Episode 511 finished after 13 time steps with total reward = 0.948 (streak 45).
# Episode 512 finished after 14 time steps with total reward = 0.944 (streak 46).
# Episode 513 finished after 14 time steps with total reward = 0.944 (streak 47).
# Episode 514 finished after 13 time steps with total reward = 0.948 (streak 48).
# Episode 515 finished after 13 time steps with total reward = 0.948 (streak 49).
# Episode 516 finished after 14 time steps with total reward = 0.944 (streak 50).
# Episode 517 finished after 13 time steps with total reward = 0.948 (streak 51).
# Episode 518 finished after 13 time steps with total reward = 0.948 (streak 52).
# Episode 519 finished after 13 time steps with total reward = 0.948 (streak 53).
# Episode 520 finished after 13 time steps with total reward = 0.948 (streak 54).
# Episode 521 finished after 13 time steps with total reward = 0.948 (streak 55).
# Episode 522 finished after 14 time steps with total reward = 0.944 (streak 56).
# Episode 523 finished after 13 time steps with total reward = 0.948 (streak 57).
# Episode 524 finished after 13 time steps with total reward = 0.948 (streak 58).
# Episode 525 finished after 13 time steps with total reward = 0.948 (streak 59).
# Episode 526 finished after 14 time steps with total reward = 0.944 (streak 60).
# Episode 527 finished after 13 time steps with total reward = 0.948 (streak 61).
# Episode 528 finished after 13 time steps with total reward = 0.948 (streak 62).
# Episode 529 finished after 13 time steps with total reward = 0.948 (streak 63).
# Episode 530 finished after 13 time steps with total reward = 0.948 (streak 64).
# Episode 531 finished after 13 time steps with total reward = 0.948 (streak 65).
# Episode 532 finished after 13 time steps with total reward = 0.948 (streak 66).
# Episode 533 finished after 13 time steps with total reward = 0.948 (streak 67).
# Episode 534 finished after 13 time steps with total reward = 0.948 (streak 68).
# Episode 535 finished after 13 time steps with total reward = 0.948 (streak 69).
# Episode 536 finished after 13 time steps with total reward = 0.948 (streak 70).
# Episode 537 finished after 13 time steps with total reward = 0.948 (streak 71).
# Episode 538 finished after 13 time steps with total reward = 0.948 (streak 72).
# Episode 539 finished after 13 time steps with total reward = 0.948 (streak 73).
# Episode 540 finished after 13 time steps with total reward = 0.948 (streak 74).
# Episode 541 finished after 13 time steps with total reward = 0.948 (streak 75).
# Episode 542 finished after 13 time steps with total reward = 0.948 (streak 76).
# Episode 543 finished after 13 time steps with total reward = 0.948 (streak 77).
# Episode 544 finished after 13 time steps with total reward = 0.948 (streak 78).
# Episode 545 finished after 13 time steps with total reward = 0.948 (streak 79).
# Episode 546 finished after 13 time steps with total reward = 0.948 (streak 80).
# Episode 547 finished after 13 time steps with total reward = 0.948 (streak 81).
# Episode 548 finished after 13 time steps with total reward = 0.948 (streak 82).
# Episode 549 finished after 13 time steps with total reward = 0.948 (streak 83).
# Episode 550 finished after 13 time steps with total reward = 0.948 (streak 84).
# Episode 551 finished after 14 time steps with total reward = 0.944 (streak 85).
# Episode 552 finished after 13 time steps with total reward = 0.948 (streak 86).
# Episode 553 finished after 13 time steps with total reward = 0.948 (streak 87).
# Episode 554 finished after 13 time steps with total reward = 0.948 (streak 88).
# Episode 555 finished after 13 time steps with total reward = 0.948 (streak 89).
# Episode 556 finished after 13 time steps with total reward = 0.948 (streak 90).
# Episode 557 finished after 13 time steps with total reward = 0.948 (streak 91).
# Episode 558 finished after 13 time steps with total reward = 0.948 (streak 92).
# Episode 559 finished after 13 time steps with total reward = 0.948 (streak 93).
# Episode 560 finished after 13 time steps with total reward = 0.948 (streak 94).
# Episode 561 finished after 13 time steps with total reward = 0.948 (streak 95).
# Episode 562 finished after 13 time steps with total reward = 0.948 (streak 96).
# Episode 563 finished after 13 time steps with total reward = 0.948 (streak 97).
# Episode 564 finished after 13 time steps with total reward = 0.948 (streak 98).
# Episode 565 finished after 13 time steps with total reward = 0.948 (streak 99).
# Episode 566 finished after 13 time steps with total reward = 0.948 (streak 100).

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (567,)
# explore_rate Shape:  (567,)
# num_streaks Shape:  (567,)
# length_episode Shape:  (567,)

# %% [markdown]
# ## Value Function

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()

grid = np.zeros((5,5))
    
for i in range (5):
    for j in range (5):
        grid[i,j] = np.argmax(Q[i,j])
        

blue_patch = mpatches.Patch(color='blue', label='Azul - Baixo')
green_patch = mpatches.Patch(color='green', label='Verde - Direita')
yellow_patch = mpatches.Patch(color='yellow', label='Amarelo - Esquerda')
purple_patch = mpatches.Patch(color='purple', label='Roxo - Cima')

plt.legend(handles=[blue_patch,green_patch,yellow_patch,purple_patch])


ax.legend(loc="upper right")
ax.set_xlabel("X",fontsize = 10)
ax.set_ylabel("Y",fontsize = 10)
ax.set_title("Mapa de direções",fontsize = 20)
ax.figure.set_size_inches(10,10)
fig.tight_layout()
plt.imshow(grid.T)  
plt.savefig(f"{SAVING_RESULTS_IMAGE_FODLER}/directions_map")
plt.show()
plt.clf()
# Out:
# No handles with labels found to put in legend.
