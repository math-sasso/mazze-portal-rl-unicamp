# %% [markdown]
# # $$ Q - Learning $$

# %% [markdown]
# ## Imports

# %%
# imports from libs
import sys
import numpy as np
import math
import random
import gym
import gym_maze
import os

# imports from project
from utils.plotting import plot_line_graphs_overlayed
from utils.file_management import create_folder_structure
from utils.file_management import save_nparray_to_folder

# %% [markdown]
# ## Setting Saving Directory

# %%
cwd = os.getcwd()
SAVING_RESULTS_FODLER = os.path.join(cwd,"results","Q_LEANING")
SAVING_RESULTS_FODLER
# Out:
# 'c:\\Users\\msasso\\Desktop\\mazze-portal-rl-unicamp\\results\\Q_LEANING'

# %% [markdown]
# ## Constants

# %%
# Initialize the "maze" environment
env = gym.make("maze-random-10x10-plus-v0")

'''
Defining the environment related constants
'''
# Number of discrete states (bucket) per state dimension
MAZE_SIZE = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
NUM_BUCKETS = MAZE_SIZE  # one bucket per grid

# Number of discrete actions
NUM_ACTIONS = env.action_space.n  # ["N", "S", "E", "W"]
# Bounds for each discrete state
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))

'''
Learning related constants
'''
MIN_EXPLORE_RATE = 0.001
MIN_LEARNING_RATE = 0.2
DECAY_FACTOR = np.prod(MAZE_SIZE, dtype=float) / 10.0

'''
Defining the simulation related constants
'''
NUM_EPISODES = 1000
MAX_T = np.prod(MAZE_SIZE, dtype=int) * 100
STREAK_TO_END = 100
SOLVED_T = np.prod(MAZE_SIZE, dtype=int)
DEBUG_MODE = 0
RENDER_MAZE = False
ENABLE_RECORDING = False

'''
Q-Learning Related Constants
'''
DISCOUNT_FACTOR = 0.99

'''
CREATING RESULTS SAVING FOLDERS
'''
SAVING_RESULTS_IMAGE_FODLER = os.path.join(SAVING_RESULTS_FODLER,"images")
SAVING_RESULTS_VIDEO_FODLER = os.path.join(SAVING_RESULTS_FODLER,"videos")
SAVING_RESULTS_ARRAY_FODLER = os.path.join(SAVING_RESULTS_FODLER,"arrays")
create_folder_structure(SAVING_RESULTS_IMAGE_FODLER)
create_folder_structure(SAVING_RESULTS_VIDEO_FODLER)
create_folder_structure(SAVING_RESULTS_ARRAY_FODLER)

'''
ENABLE RECORDING
'''
if ENABLE_RECORDING:
    env = gym.wrappers.Monitor(env,SAVING_RESULTS_VIDEO_FODLER, force=True)
# Out:
# pygame 2.0.0 (SDL 2.0.12, python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Algorithm Simulation

# %%
def simulate(discount_factor:float= 0.99):
    """Simulate Q-Learning Algorythim .

    Args:
        discount_factor (float): gamma.

    Returns:
        np.array(reward_episode_list): Numpy array with the episodes rewards
        np.array(explore_rate_episode_list): Numpy array with the episodes explore rates
        np.array(learning_rate_episode_list): Numpy array with the episodes learning rates
        np.array(num_streaks_episode_list): Numpy array with the episodes number of mazze completions
        np.array(length_episode_list): Numpy array with the episodes lengths
    """

    #creating episodes results lists
    
    reward_episode_list = []
    explore_rate_episode_list = []
    learning_rate_episode_list = []
    num_streaks_episode_list = []
    length_episode_list = []

    # Instantiating the learning related parameters
    learning_rate = get_learning_rate(0)
    explore_rate = get_explore_rate(0)

    # Render tha maze
    env.render()

    # Initialize q_table
    q_table = np.zeros(NUM_BUCKETS + (NUM_ACTIONS,), dtype=float)

    #Initializain num streaks
    num_streaks= 0

    for episode in range(NUM_EPISODES):

        # Reset the environment
        obv = env.reset()

        # the initial state
        state_0 = state_to_bucket(obv)
        total_reward = 0


        for t in range(MAX_T):

            # Select an action
            action = epsilon_greedy_police(state_0, explore_rate,q_table)

            # execute the action
            obv, reward, done, _ = env.step(action)

            # Observe the result
            state = state_to_bucket(obv)
            total_reward += reward

            # Update the Q based on the result
            best_q = np.amax(q_table[state])
            q_table[state_0 + (action,)] += learning_rate * (reward + discount_factor * (best_q) - q_table[state_0 + (action,)])

            # Setting up for the next iteration
            state_0 = state

            # Print data
            if DEBUG_MODE == 2:
                print("\nEpisode = %d" % episode)
                print("t = %d" % t)
                print("Action: %d" % action)
                print("State: %s" % str(state))
                print("Reward: %f" % reward)
                print("Best Q: %f" % best_q)
                print("Explore rate: %f" % explore_rate)
                print("Learning rate: %f" % learning_rate)
                print("Streaks: %d" % num_streaks)
                print("")

            elif DEBUG_MODE == 1:
                if done or t >= MAX_T - 1:
                    print("\nEpisode = %d" % episode)
                    print("t = %d" % t)
                    print("Explore rate: %f" % explore_rate)
                    print("Learning rate: %f" % learning_rate)
                    print("Streaks: %d" % num_streaks)
                    print("Total reward: %f" % total_reward)
                    print("")

            # Render tha maze
            if RENDER_MAZE:
                env.render()

            if env.is_game_over():
                sys.exit()

            if done:
                print("Episode %d finished after %f time steps with total reward = %f (streak %d)."
                      % (episode, t, total_reward, num_streaks))
                num_streaks_copy = num_streaks
                if t <= SOLVED_T:
                    num_streaks += 1
                else:
                    num_streaks = 0
                break

            elif t >= MAX_T - 1:
                print("Episode %d timed out at %d with total reward = %f."
                      % (episode, t, total_reward))

        # Appending Episode values to the list
        reward_episode_list.append(total_reward)
        explore_rate_episode_list.append(explore_rate)
        learning_rate_episode_list.append(learning_rate)
        num_streaks_episode_list.append(num_streaks_copy)
        length_episode_list.append(t)

        # It's considered done when it's solved over 120 times consecutively
        if num_streaks > STREAK_TO_END:
            break

        # Update parameters
        explore_rate = get_explore_rate(episode)
        learning_rate = get_learning_rate(episode)


    print("FINAL ACTION TABLE \n")
    acts = ["N", "S", "E", "W"]
    for i in range(q_table.shape[2]):
        print(f"Action {acts[i]} table \n {q_table[:,:,i]}\n")

    return (np.array(reward_episode_list),
            np.array(explore_rate_episode_list),
            np.array(learning_rate_episode_list),
            np.array(num_streaks_episode_list),
            np.array(length_episode_list))

# %% [markdown]
# ## Epsilon Greed Exploration

# %%
def epsilon_greedy_police(state, explore_rate,q_table):
    # Select a random action
    if random.random() < explore_rate:
        action = env.action_space.sample()
    # Select the action with the highest q
    else:
        action = int(np.argmax(q_table[state]))
    return action

# %% [markdown]
# ## Updating EXPLORE_RATE and LEARNING_RATE

# %%
def get_explore_rate(t):
    return max(MIN_EXPLORE_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %%
def get_learning_rate(t):
    return max(MIN_LEARNING_RATE, min(0.8, 1.0 - math.log10((t+1)/DECAY_FACTOR)))

# %% [markdown]
# ## Function that returns the actual state

# %%
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_BUCKETS[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_BUCKETS[i]-1)*STATE_BOUNDS[i][0]/bound_width
            scaling = (NUM_BUCKETS[i]-1)/bound_width
            bucket_index = int(round(scaling*state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

# %% [markdown]
# ## Running

# %%
reward_episode_array,explore_rate_episode_array,learning_rate_episode_array,num_streaks_episode_array,length_episode_array = \
        simulate(discount_factor = DISCOUNT_FACTOR)

if ENABLE_RECORDING:
    env.monitor.close()
# Out:
# Episode 0 finished after 185.000000 time steps with total reward = 0.815000 (streak 0).
# Episode 1 finished after 1093.000000 time steps with total reward = -0.093000 (streak 0).
# Episode 2 finished after 567.000000 time steps with total reward = 0.433000 (streak 0).
# Episode 3 finished after 107.000000 time steps with total reward = 0.893000 (streak 0).
# Episode 4 finished after 22.000000 time steps with total reward = 0.978000 (streak 0).
# Episode 5 finished after 159.000000 time steps with total reward = 0.841000 (streak 1).
# Episode 6 finished after 98.000000 time steps with total reward = 0.902000 (streak 0).
# Episode 7 finished after 33.000000 time steps with total reward = 0.967000 (streak 1).
# Episode 8 finished after 157.000000 time steps with total reward = 0.843000 (streak 2).
# Episode 9 finished after 42.000000 time steps with total reward = 0.958000 (streak 0).
# Episode 10 finished after 92.000000 time steps with total reward = 0.908000 (streak 1).
# Episode 11 finished after 59.000000 time steps with total reward = 0.941000 (streak 2).
# Episode 12 finished after 26.000000 time steps with total reward = 0.974000 (streak 3).
# Episode 13 finished after 148.000000 time steps with total reward = 0.852000 (streak 4).
# Episode 14 finished after 58.000000 time steps with total reward = 0.942000 (streak 0).
# Episode 15 finished after 212.000000 time steps with total reward = 0.788000 (streak 1).
# Episode 16 finished after 22.000000 time steps with total reward = 0.978000 (streak 0).
# Episode 17 finished after 35.000000 time steps with total reward = 0.965000 (streak 1).
# Episode 18 finished after 16.000000 time steps with total reward = 0.984000 (streak 2).
# Episode 19 finished after 68.000000 time steps with total reward = 0.932000 (streak 3).
# Episode 20 finished after 39.000000 time steps with total reward = 0.961000 (streak 4).
# Episode 21 finished after 11.000000 time steps with total reward = 0.989000 (streak 5).
# Episode 22 finished after 9.000000 time steps with total reward = 0.991000 (streak 6).
# Episode 23 finished after 38.000000 time steps with total reward = 0.962000 (streak 7).
# Episode 24 finished after 11.000000 time steps with total reward = 0.989000 (streak 8).
# Episode 25 finished after 24.000000 time steps with total reward = 0.976000 (streak 9).
# Episode 26 finished after 45.000000 time steps with total reward = 0.955000 (streak 10).
# Episode 27 finished after 14.000000 time steps with total reward = 0.986000 (streak 11).
# Episode 28 finished after 20.000000 time steps with total reward = 0.980000 (streak 12).
# Episode 29 finished after 34.000000 time steps with total reward = 0.966000 (streak 13).
# Episode 30 finished after 15.000000 time steps with total reward = 0.985000 (streak 14).
# Episode 31 finished after 19.000000 time steps with total reward = 0.981000 (streak 15).
# Episode 32 finished after 11.000000 time steps with total reward = 0.989000 (streak 16).
# Episode 33 finished after 19.000000 time steps with total reward = 0.981000 (streak 17).
# Episode 34 finished after 10.000000 time steps with total reward = 0.990000 (streak 18).
# Episode 35 finished after 13.000000 time steps with total reward = 0.987000 (streak 19).
# Episode 36 finished after 8.000000 time steps with total reward = 0.992000 (streak 20).
# Episode 37 finished after 10.000000 time steps with total reward = 0.990000 (streak 21).
# Episode 38 finished after 12.000000 time steps with total reward = 0.988000 (streak 22).
# Episode 39 finished after 11.000000 time steps with total reward = 0.989000 (streak 23).
# Episode 40 finished after 12.000000 time steps with total reward = 0.988000 (streak 24).
# Episode 41 finished after 16.000000 time steps with total reward = 0.984000 (streak 25).
# Episode 42 finished after 8.000000 time steps with total reward = 0.992000 (streak 26).
# Episode 43 finished after 20.000000 time steps with total reward = 0.980000 (streak 27).
# Episode 44 finished after 13.000000 time steps with total reward = 0.987000 (streak 28).
# Episode 45 finished after 10.000000 time steps with total reward = 0.990000 (streak 29).
# Episode 46 finished after 38.000000 time steps with total reward = 0.962000 (streak 30).
# Episode 47 finished after 18.000000 time steps with total reward = 0.982000 (streak 31).
# Episode 48 finished after 8.000000 time steps with total reward = 0.992000 (streak 32).
# Episode 49 finished after 9.000000 time steps with total reward = 0.991000 (streak 33).
# Episode 50 finished after 13.000000 time steps with total reward = 0.987000 (streak 34).
# Episode 51 finished after 13.000000 time steps with total reward = 0.987000 (streak 35).
# Episode 52 finished after 16.000000 time steps with total reward = 0.984000 (streak 36).
# Episode 53 finished after 8.000000 time steps with total reward = 0.992000 (streak 37).
# Episode 54 finished after 8.000000 time steps with total reward = 0.992000 (streak 38).
# Episode 55 finished after 13.000000 time steps with total reward = 0.987000 (streak 39).
# Episode 56 finished after 9.000000 time steps with total reward = 0.991000 (streak 40).
# Episode 57 finished after 9.000000 time steps with total reward = 0.991000 (streak 41).
# Episode 58 finished after 9.000000 time steps with total reward = 0.991000 (streak 42).
# Episode 59 finished after 9.000000 time steps with total reward = 0.991000 (streak 43).
# Episode 60 finished after 11.000000 time steps with total reward = 0.989000 (streak 44).
# Episode 61 finished after 7.000000 time steps with total reward = 0.993000 (streak 45).
# Episode 62 finished after 9.000000 time steps with total reward = 0.991000 (streak 46).
# Episode 63 finished after 11.000000 time steps with total reward = 0.989000 (streak 47).
# Episode 64 finished after 7.000000 time steps with total reward = 0.993000 (streak 48).
# Episode 65 finished after 9.000000 time steps with total reward = 0.991000 (streak 49).
# Episode 66 finished after 13.000000 time steps with total reward = 0.987000 (streak 50).
# Episode 67 finished after 11.000000 time steps with total reward = 0.989000 (streak 51).
# Episode 68 finished after 10.000000 time steps with total reward = 0.990000 (streak 52).
# Episode 69 finished after 7.000000 time steps with total reward = 0.993000 (streak 53).
# Episode 70 finished after 7.000000 time steps with total reward = 0.993000 (streak 54).
# Episode 71 finished after 9.000000 time steps with total reward = 0.991000 (streak 55).
# Episode 72 finished after 7.000000 time steps with total reward = 0.993000 (streak 56).
# Episode 73 finished after 7.000000 time steps with total reward = 0.993000 (streak 57).
# Episode 74 finished after 7.000000 time steps with total reward = 0.993000 (streak 58).
# Episode 75 finished after 14.000000 time steps with total reward = 0.986000 (streak 59).
# Episode 76 finished after 8.000000 time steps with total reward = 0.992000 (streak 60).
# Episode 77 finished after 11.000000 time steps with total reward = 0.989000 (streak 61).
# Episode 78 finished after 7.000000 time steps with total reward = 0.993000 (streak 62).
# Episode 79 finished after 8.000000 time steps with total reward = 0.992000 (streak 63).
# Episode 80 finished after 7.000000 time steps with total reward = 0.993000 (streak 64).
# Episode 81 finished after 8.000000 time steps with total reward = 0.992000 (streak 65).
# Episode 82 finished after 13.000000 time steps with total reward = 0.987000 (streak 66).
# Episode 83 finished after 7.000000 time steps with total reward = 0.993000 (streak 67).
# Episode 84 finished after 7.000000 time steps with total reward = 0.993000 (streak 68).
# Episode 85 finished after 7.000000 time steps with total reward = 0.993000 (streak 69).
# Episode 86 finished after 7.000000 time steps with total reward = 0.993000 (streak 70).
# Episode 87 finished after 7.000000 time steps with total reward = 0.993000 (streak 71).
# Episode 88 finished after 7.000000 time steps with total reward = 0.993000 (streak 72).
# Episode 89 finished after 7.000000 time steps with total reward = 0.993000 (streak 73).
# Episode 90 finished after 7.000000 time steps with total reward = 0.993000 (streak 74).
# Episode 91 finished after 7.000000 time steps with total reward = 0.993000 (streak 75).
# Episode 92 finished after 8.000000 time steps with total reward = 0.992000 (streak 76).
# Episode 93 finished after 7.000000 time steps with total reward = 0.993000 (streak 77).
# Episode 94 finished after 7.000000 time steps with total reward = 0.993000 (streak 78).
# Episode 95 finished after 7.000000 time steps with total reward = 0.993000 (streak 79).
# Episode 96 finished after 7.000000 time steps with total reward = 0.993000 (streak 80).
# Episode 97 finished after 7.000000 time steps with total reward = 0.993000 (streak 81).
# Episode 98 finished after 7.000000 time steps with total reward = 0.993000 (streak 82).
# Episode 99 finished after 7.000000 time steps with total reward = 0.993000 (streak 83).
# Episode 100 finished after 7.000000 time steps with total reward = 0.993000 (streak 84).
# Episode 101 finished after 7.000000 time steps with total reward = 0.993000 (streak 85).
# Episode 102 finished after 7.000000 time steps with total reward = 0.993000 (streak 86).
# Episode 103 finished after 7.000000 time steps with total reward = 0.993000 (streak 87).
# Episode 104 finished after 7.000000 time steps with total reward = 0.993000 (streak 88).
# Episode 105 finished after 7.000000 time steps with total reward = 0.993000 (streak 89).
# Episode 106 finished after 7.000000 time steps with total reward = 0.993000 (streak 90).
# Episode 107 finished after 7.000000 time steps with total reward = 0.993000 (streak 91).
# Episode 108 finished after 7.000000 time steps with total reward = 0.993000 (streak 92).
# Episode 109 finished after 7.000000 time steps with total reward = 0.993000 (streak 93).
# Episode 110 finished after 7.000000 time steps with total reward = 0.993000 (streak 94).
# Episode 111 finished after 7.000000 time steps with total reward = 0.993000 (streak 95).
# Episode 112 finished after 7.000000 time steps with total reward = 0.993000 (streak 96).
# Episode 113 finished after 7.000000 time steps with total reward = 0.993000 (streak 97).
# Episode 114 finished after 7.000000 time steps with total reward = 0.993000 (streak 98).
# Episode 115 finished after 7.000000 time steps with total reward = 0.993000 (streak 99).
# Episode 116 finished after 7.000000 time steps with total reward = 0.993000 (streak 100).
# FINAL ACTION TABLE
#
# Action N table
#  [[ 9.15012960e-01  9.15011767e-01 -6.05849339e-03  1.23973682e-01
#    5.76951243e-01  7.07822262e-01 -3.70464965e-03 -4.31275602e-03
#   -4.48039832e-03 -4.38233843e-03]
#  [ 9.25271657e-01  9.25271675e-01  9.35628163e-01  9.46088957e-01
#    9.50238757e-01  7.71232487e-01 -3.68873023e-03 -3.72511601e-03
#   -3.72486322e-03 -4.27603051e-03]
#  [ 9.10442141e-01  9.25213280e-01  9.24839931e-01  7.24771468e-01
#    5.92613770e-01  7.46964438e-01 -2.72687401e-03 -2.26181120e-03
#   -4.66410597e-03 -5.15313068e-03]
00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -5.01347297e-03 -4.53975653e-03
#   -3.50745164e-03 -3.54272519e-03  2.54999299e-01 -8.00000000e-04
#    9.79774175e-01  0.00000000e+00]]
#
# Action W table
#  [[ 9.15018930e-01  8.73399282e-01  1.56280969e-01 -4.84052889e-03
#   -4.11512972e-03 -3.71254227e-03 -4.22014208e-03 -4.38020718e-03
#   -4.98143282e-03 -4.13013685e-03]
#  [ 9.15018908e-01  9.35628053e-01  9.46089022e-01  8.29123879e-01
#    8.37886069e-01 -3.71097495e-03 -3.76393370e-03 -4.22154459e-03
#   -5.33704107e-03 -4.29447624e-03]
#  [ 9.25271743e-01  9.35628060e-01  8.92713526e-01  9.55618494e-01
#    6.35804653e-01 -2.69417718e-03 -3.64942920e-03 -2.41265869e-03
#   -4.63787917e-03 -4.31238506e-03]
#  [-2.44460544e-03  8.02011954e-01 -3.19984640e-03  9.29498893e-01
#   -3.16180439e-03  8.88446775e-01 -2.89253509e-03 -2.35449344e-03
#   -5.42967123e-03 -4.44650582e-03]
#  [-2.69129318e-03 -4.72381991e-03 -3.79022508e-03  7.07425129e-01
#    3.44954762e-01 -2.43153920e-03 -1.87904000e-03 -1.79066880e-03
#   -2.38085120e-03 -4.23978534e-03]
#  [-2.37983744e-03 -9.60000000e-04 -4.59149109e-03 -3.70859151e-03
#   -4.27949294e-03 -3.50908283e-03 -2.50655744e-03 -2.47470080e-03
#   -1.63328000e-03  6.94538308e-01]
#  [ 0.00000000e+00 -8.00000000e-04 -3.74660015e-03 -4.33895198e-03
#   -3.81229955e-03  5.75774768e-01 -2.60911276e-03 -1.76000000e-03
#    9.54704306e-01  8.90987282e-01]
#  [ 0.00000000e+00  0.00000000e+00 -4.44904494e-03 -4.70637536e-03
#   -1.93766400e-03  4.79416653e-01  8.43418989e-01  9.56647406e-01
#    9.56654143e-01  9.58905116e-01]
#  [ 0.00000000e+00  0.00000000e+00 -3.78023260e-03 -4.54434752e-03
#   -2.69421773e-03 -3.44269562e-03 -9.60000000e-04  9.35399642e-01
#    9.67324526e-01  9.76642211e-01]
#  [ 0.00000000e+00  0.00000000e+00 -4.85996898e-03 -4.40988637e-03
#   -3.38665593e-03 -3.59097336e-03 -9.92000000e-04  9.66446319e-01
#    7.82162648e-01  0.00000000e+00]]

# %%
graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"reward_episode")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [reward_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Reward",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Episode Reward by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"explore_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [explore_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Exploration Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Exploration Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"learning_rate_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [learning_rate_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Learning Rate",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Learning Rate by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"num_streaks_episode_array")
plot_line_graphs_overlayed(x_list =[range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [num_streaks_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Number of streaks",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Number of streaks by episode" ,
                            graph_saving_path = graph_saving_path)


graph_saving_path = os.path.join(SAVING_RESULTS_IMAGE_FODLER,"length_episode_array")
plot_line_graphs_overlayed(x_list = [range(NUM_EPISODES)[:len(num_streaks_episode_array)]],
                            y_list = [length_episode_array],
                            x_axe_name="Episode", 
                            y_axe_name="Length of episode",
                            legends = ["None_Marker"],
                            title = "Q-Learning: Length of episode by episode" ,
                            graph_saving_path = graph_saving_path)

# %% [markdown]
# ## Saving numpy arrays from results

# %%
save_nparray_to_folder(reward_episode_array,SAVING_RESULTS_ARRAY_FODLER,"reward_episode")
save_nparray_to_folder(explore_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"explore_rate")
save_nparray_to_folder(learning_rate_episode_array,SAVING_RESULTS_ARRAY_FODLER,"learning_rate")
save_nparray_to_folder(num_streaks_episode_array,SAVING_RESULTS_ARRAY_FODLER,"num_streaks")
save_nparray_to_folder(length_episode_array,SAVING_RESULTS_ARRAY_FODLER,"length_episode")
# Out:
# reward_episode Shape:  (117,)
# explore_rate Shape:  (117,)
# learning_rate Shape:  (117,)
# num_streaks Shape:  (117,)
# length_episode Shape:  (117,)
